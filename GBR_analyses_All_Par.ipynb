# %% [markdown]
# # ELP MODEL 1

# %%
import pandas as pd
dt1= pd.read_csv("Model1 ELP/Transformed_recoverd_param_ELP_S1_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv")
dt2= pd.read_csv("Model1 ELP/Transformed_recoverd_param_ELP_S2_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv")
dt1.head()
# Out:
#    Unnamed: 0  participant        v1        v2        zr         a       ndt  \
# 0           0          1.0  1.025863 -1.611488  0.543450  1.225113  0.432995
# 1           1          2.0  0.870676 -1.174652  0.502175  1.092706  0.483172
# 2           2          3.0  0.777673 -1.227016  0.637279  1.678526  0.573637
# 3           3          4.0  1.221097 -1.740166  0.579341  1.353762  0.503063
# 4           4          5.0  2.560879 -3.416537  0.637399  0.913316  0.426688
#
#        sndt     alpha  accuracy_percentage  ...  mean_Crror  log_alpha_mean  \
# 0  0.045539  1.985247             0.843669  ...    0.802257        0.685545
# 1  0.061320  1.936546             0.771867  ...    0.807534        0.660348
# 2  0.101946  1.990209             0.832388  ...    1.249028        0.688103
# 3  0.049822  1.996699             0.881260  ...    0.944470        0.691350
# 4  0.035511  1.881057             0.943494  ...    0.585706        0.631265
#
# ...

# %%
import GBRAll


session1 = 'Model1 ELP/Transformed_recoverd_param_ELP_S1_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'
session2 = 'Model1 ELP/Transformed_recoverd_param_ELP_S2_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'



GBRAll.analyze_dataset(session1, session2)
# Out:
# GradientBoostingRegressor R^2 on TRAIN: 0.922
# GradientBoostingRegressor R^2 on TEST:  0.741
#
# Gini-based Feature Importances:
#   alpha_s1: 0.310
#   a_mean_s1: 0.034
#   a_mean_s2: 0.220
#   ndt_mean_s1: 0.028
#   ndt_mean_s2: 0.182
#   v1_mean_s1: 0.025
#   v1_mean_s2: 0.044
#   v2_mean_s1: 0.013
#   v2_mean_s2: 0.144
#
# Permutation Importances (Test set):
#   a_mean_s2: Mean=0.3648, std=0.0370
#   ndt_mean_s2: Mean=0.3243, std=0.0364
#   alpha_s1: Mean=0.2946, std=0.0343
#   v2_mean_s2: Mean=0.1468, std=0.0080
#   a_mean_s1: Mean=0.0419, std=0.0083
#   ndt_mean_s1: Mean=0.0241, std=0.0052
#   v1_mean_s2: Mean=0.0193, std=0.0086
#   v1_mean_s1: Mean=0.0157, std=0.0070
#   v2_mean_s1: Mean=0.0124, std=0.0032

# %% [markdown]
# # ELP MODEL 2

# %%
import GBRAll


session1 = 'Model2 ELP/Transformed_recoverd_param_ELP_S1_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'
session2 = 'Model2 ELP/Transformed_recoverd_param_ELP_S2_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'




GBRAll.analyze_dataset(session1, session2)
# Out:
# GradientBoostingRegressor R^2 on TRAIN: 0.923
# GradientBoostingRegressor R^2 on TEST:  0.607
#
# Gini-based Feature Importances:
#   alpha_s1: 0.479
#   a_mean_s1: 0.040
#   a_mean_s2: 0.132
#   ndt_mean_s1: 0.042
#   ndt_mean_s2: 0.190
#   v1_mean_s1: 0.029
#   v1_mean_s2: 0.053
#   v2_mean_s1: 0.011
#   v2_mean_s2: 0.025
#
# Permutation Importances (Test set):
#   alpha_s1: Mean=0.4141, std=0.0373
#   ndt_mean_s2: Mean=0.4036, std=0.0347
#   a_mean_s2: Mean=0.1173, std=0.0167
#   ndt_mean_s1: Mean=0.0325, std=0.0112
#   v2_mean_s2: Mean=0.0278, std=0.0027
#   v1_mean_s1: Mean=0.0215, std=0.0109
#   v1_mean_s2: Mean=0.0151, std=0.0046
#   a_mean_s1: Mean=0.0072, std=0.0048
#   v2_mean_s1: Mean=-0.0165, std=0.0055

# %% [markdown]
# # LDT Model 1

# %%
import GBRAll

# Specify the paths to your session CSV files:
session1 = 'Model1 LDT RMT/ldt_session_1_data_transformed.csv'
session2 = 'Model1 LDT RMT/ldt_session_2_data_transformed.csv'


GBRAll.analyze_dataset(session1, session2)
# Out:
# GradientBoostingRegressor R^2 on TRAIN: 0.999
# GradientBoostingRegressor R^2 on TEST:  -0.185
#
# Gini-based Feature Importances:
#   alpha_s1: 0.374
#   a_mean_s1: 0.045
#   a_mean_s2: 0.103
#   ndt_mean_s1: 0.036
#   ndt_mean_s2: 0.238
#   v1_mean_s1: 0.054
#   v1_mean_s2: 0.054
#   v2_mean_s1: 0.047
#   v2_mean_s2: 0.050
#
# Permutation Importances (Test set):
#   ndt_mean_s2: Mean=0.2163, std=0.2168
#   alpha_s1: Mean=0.1997, std=0.2642
#   a_mean_s1: Mean=0.0746, std=0.0182
#   v2_mean_s1: Mean=0.0106, std=0.0271
#   ndt_mean_s1: Mean=0.0053, std=0.0297
#   a_mean_s2: Mean=-0.0433, std=0.0989
#   v1_mean_s1: Mean=-0.0856, std=0.0733
#   v1_mean_s2: Mean=-0.0937, std=0.1147
#   v2_mean_s2: Mean=-0.1387, std=0.0918

# %% [markdown]
# # LDT Model 2

# %%
import GBRAll


session1 = 'Model2 LDT RMT/EZ_lexical_decision_part1_transformed.csv'
session2 = 'Model2 LDT RMT/EZ_lexical_decision_part2_transformed.csv'




GBRAll.analyze_dataset(session1, session2)
# Out:
# GradientBoostingRegressor R^2 on TRAIN: 0.999
# GradientBoostingRegressor R^2 on TEST:  0.150
#
# Gini-based Feature Importances:
#   alpha_s1: 0.499
#   a_mean_s1: 0.069
#   a_mean_s2: 0.046
#   ndt_mean_s1: 0.043
#   ndt_mean_s2: 0.175
#   v1_mean_s1: 0.048
#   v1_mean_s2: 0.025
#   v2_mean_s1: 0.038
#   v2_mean_s2: 0.058
#
# Permutation Importances (Test set):
#   alpha_s1: Mean=0.3873, std=0.1535
#   ndt_mean_s2: Mean=0.1885, std=0.0699
#   v2_mean_s1: Mean=0.1451, std=0.0395
#   v1_mean_s2: Mean=0.0481, std=0.0190
#   a_mean_s1: Mean=0.0348, std=0.0194
#   v1_mean_s1: Mean=0.0337, std=0.0465
#   ndt_mean_s1: Mean=0.0191, std=0.0235
#   a_mean_s2: Mean=-0.0221, std=0.0429
#   v2_mean_s2: Mean=-0.0627, std=0.0767

# %% [markdown]
# # RMT Model 1

# %%
pd.read_csv("Model1 LDT RMT/rmt_session_1_data_transformed.csv")
# Out:
#      Unnamed: 0                      Experiment   v1_mean   v2_mean   zr_mean  \
# 0           171   001_class_pictures_part_1.dat  1.416757 -2.303725  0.491326
# 1           400   002_class_pictures_part_1.dat  1.086745 -2.807873  0.630802
# 2           355   003_class_pictures_part_1.dat  1.057104 -2.014052  0.622879
# 3            86   004_class_pictures_part_1.dat  2.481291 -2.274865  0.503201
# 4           401   005_class_pictures_part_1.dat  1.698414 -1.846684  0.634036
# ..          ...                             ...       ...       ...       ...
# 98          266  4009_class_pictures_part_1.dat  2.015764 -2.392402  0.588073
# 99          269  4010_class_pictures_part_1.dat  2.790163 -2.926470  0.550582
# 100          83  4011_class_pictures_part_1.dat  0.773485 -0.965195  0.386991
# 101         411  4012_class_pictures_part_1.dat  1.862724 -2.209588  0.531819
# 102         246  4013_class_pictures_part_1.dat  2.508516 -1.906608  0.478068
#
# ...

# %%
import GBRAll


session1 = 'Model1 LDT RMT/rmt_session_1_data_transformed.csv'
session2 = 'Model1 LDT RMT/rmt_session_2_data_transformed.csv'




GBRAll.analyze_dataset(session1, session2)
# Out:
# GradientBoostingRegressor R^2 on TRAIN: 0.999
# GradientBoostingRegressor R^2 on TEST:  0.127
#
# Gini-based Feature Importances:
#   alpha_s1: 0.063
#   a_mean_s1: 0.201
#   a_mean_s2: 0.058
#   ndt_mean_s1: 0.028
#   ndt_mean_s2: 0.274
#   v1_mean_s1: 0.041
#   v1_mean_s2: 0.245
#   v2_mean_s1: 0.044
#   v2_mean_s2: 0.046
#
# Permutation Importances (Test set):
#   v1_mean_s2: Mean=0.1368, std=0.0743
#   v2_mean_s1: Mean=0.1010, std=0.0486
#   ndt_mean_s2: Mean=0.0968, std=0.0192
#   a_mean_s2: Mean=0.0701, std=0.0496
#   a_mean_s1: Mean=0.0488, std=0.0569
#   v2_mean_s2: Mean=0.0249, std=0.0185
#   alpha_s1: Mean=0.0148, std=0.0098
#   ndt_mean_s1: Mean=-0.0071, std=0.0063
#   v1_mean_s1: Mean=-0.0408, std=0.0307

# %% [markdown]
# # RMT Model 2

# %%
import GBRAll


session1 = 'Model2 LDT RMT/EZ_recognition_memory_part1_transformed.csv'
session2 = 'Model2 LDT RMT/EZ_recognition_memory_part2_transformed.csv'



GBRAll.analyze_dataset(session1, session2)
# Out:
# GradientBoostingRegressor R^2 on TRAIN: 1.000
# GradientBoostingRegressor R^2 on TEST:  0.476
#
# Gini-based Feature Importances:
#   alpha_s1: 0.052
#   a_mean_s1: 0.050
#   a_mean_s2: 0.295
#   ndt_mean_s1: 0.142
#   ndt_mean_s2: 0.142
#   v1_mean_s1: 0.105
#   v1_mean_s2: 0.102
#   v2_mean_s1: 0.077
#   v2_mean_s2: 0.035
#
# Permutation Importances (Test set):
#   ndt_mean_s1: Mean=0.1255, std=0.0575
#   v2_mean_s1: Mean=0.1194, std=0.1010
#   ndt_mean_s2: Mean=0.1102, std=0.1033
#   alpha_s1: Mean=0.0534, std=0.0267
#   v1_mean_s2: Mean=0.0525, std=0.0612
#   v1_mean_s1: Mean=0.0386, std=0.0662
#   v2_mean_s2: Mean=0.0199, std=0.0090
#   a_mean_s2: Mean=0.0015, std=0.0449
#   a_mean_s1: Mean=-0.0280, std=0.0132
