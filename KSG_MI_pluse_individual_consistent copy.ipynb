# %%
# Out:
# Available columns in session 1: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s1', 'ndt_mean_s1', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s2', 'ndt_mean_s2', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: ID
# Data loaded successfully. Number of participants: 104
# Analyzing dataset: LDT Model 1
#
# Data-driven k value (sqrt(N)): 10
# Testing k values: [3, 5, 7, 10]
#
# Analyzing with k=3...
#
# Analyzing with k=5...
#
# Analyzing with k=7...
#
# Analyzing with k=10...
#
# Analysis complete.
#
# ================================================================================
# Summary Table
# ================================================================================
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>k</th>
#       <th>Raw MI (bits)</th>
#       <th>p (Raw MI)</th>
#       <th>CMI All (bits)</th>
#       <th>p (All)</th>
#       <th>Ret All (%)</th>
#       <th>CMI Thresh (bits)</th>
#       <th>p (Thresh)</th>
#       <th>Ret Thresh (%)</th>
#       <th>CMI NDT (bits)</th>
#       <th>p (NDT)</th>
#       <th>Ret NDT (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>0.628</td>
#       <td>0.0010</td>
#       <td>0.196</td>
#       <td>0.0030</td>
#       <td>31.3</td>
#       <td>0.344</td>
#       <td>0.0010</td>
#       <td>54.7</td>
#       <td>0.165</td>
#       <td>0.0030</td>
#       <td>26.3</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.638</td>
#       <td>0.0010</td>
#       <td>0.047</td>
#       <td>0.0030</td>
#       <td>7.3</td>
#       <td>0.299</td>
#       <td>0.0010</td>
#       <td>46.8</td>
#       <td>0.368</td>
#       <td>0.0010</td>
#       <td>57.6</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.540</td>
#       <td>0.0010</td>
#       <td>0.012</td>
#       <td>0.0010</td>
#       <td>2.3</td>
#       <td>0.187</td>
#       <td>0.0010</td>
#       <td>34.7</td>
#       <td>0.345</td>
#       <td>0.0010</td>
#       <td>63.8</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.477</td>
#       <td>0.0010</td>
#       <td>0.004</td>
#       <td>0.0010</td>
#       <td>0.9</td>
#       <td>0.186</td>
#       <td>0.0010</td>
#       <td>38.9</td>
#       <td>0.292</td>
#       <td>0.0010</td>
#       <td>61.1</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# Generating Plots (calling methods from KSG_MI_First.py)
# ================================================================================
# Plot generation finished. Plots should appear above.
#
# ================================================================================
# Comprehensive Text Results
# ================================================================================
#
# --- Results for k=3  ---
# Raw MI: 0.6281 bits (p=0.0010)
# CMI (All Controls): 0.1964 bits (p=0.0030), Retention: 31.3%
# CMI (Threshold Only): 0.3436 bits (p=0.0010), Retention: 54.7%
# CMI (NDT Only): 0.1652 bits (p=0.0030), Retention: 26.3%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.3226 bits (p=0.0060), Retention=51.4%
#   a_mean_s2: CMI=0.4127 bits (p=0.0010), Retention=65.7%
#   ndt_mean_s1: CMI=0.4096 bits (p=0.0020), Retention=65.2%
#   ndt_mean_s2: CMI=0.4851 bits (p=0.0010), Retention=77.2%
#
# --- Results for k=5  ---
# Raw MI: 0.6382 bits (p=0.0010)
# CMI (All Controls): 0.0467 bits (p=0.0030), Retention: 7.3%
# CMI (Threshold Only): 0.2988 bits (p=0.0010), Retention: 46.8%
# CMI (NDT Only): 0.3679 bits (p=0.0010), Retention: 57.6%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.3969 bits (p=0.0010), Retention=62.2%
#   a_mean_s2: CMI=0.2592 bits (p=0.0010), Retention=40.6%
#   ndt_mean_s1: CMI=0.4244 bits (p=0.0010), Retention=66.5%
#   ndt_mean_s2: CMI=0.3833 bits (p=0.0010), Retention=60.1%
#
# --- Results for k=7  ---
# Raw MI: 0.5403 bits (p=0.0010)
# CMI (All Controls): 0.0122 bits (p=0.0010), Retention: 2.3%
# CMI (Threshold Only): 0.1873 bits (p=0.0010), Retention: 34.7%
# CMI (NDT Only): 0.3448 bits (p=0.0010), Retention: 63.8%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.3898 bits (p=0.0010), Retention=72.1%
#   a_mean_s2: CMI=0.3009 bits (p=0.0010), Retention=55.7%
#   ndt_mean_s1: CMI=0.2959 bits (p=0.0010), Retention=54.8%
#   ndt_mean_s2: CMI=0.3911 bits (p=0.0010), Retention=72.4%
#
# --- Results for k=10 (Data-driven) ---
# Raw MI: 0.4771 bits (p=0.0010)
# CMI (All Controls): 0.0044 bits (p=0.0010), Retention: 0.9%
# CMI (Threshold Only): 0.1856 bits (p=0.0010), Retention: 38.9%
# CMI (NDT Only): 0.2917 bits (p=0.0010), Retention: 61.1%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.2257 bits (p=0.0010), Retention=47.3%
#   a_mean_s2: CMI=0.2767 bits (p=0.0010), Retention=58.0%
#   ndt_mean_s1: CMI=0.2888 bits (p=0.0010), Retention=60.5%
#   ndt_mean_s2: CMI=0.3866 bits (p=0.0010), Retention=81.0%

# %% [markdown]
# # LDT Model 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from IPython.display import display, HTML

# --- Import from your script ---
# Make sure KSG_MI_First.py is in the same directory or accessible
try:
    # We might need to reload the module if it was changed since the kernel started
    import importlib
    import KSG_MI_First
    importlib.reload(KSG_MI_First) # Reload to get the changes with plt.show()
    from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge
except ImportError:
    print("Error: Could not import from KSG_MI_First.py.")
    print("Make sure the file is in the same directory as the notebook or in the Python path.")
    # You might need to add the directory to the path if it's elsewhere:
    # import sys
    # sys.path.append('/path/to/your/script/directory')
    # from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge

# --- Configuration ---
# <<< IMPORTANT: UPDATE THESE PATHS >>>
session1_path = 'Model1 LDT RMT/ldt_session_1_data_transformed.csv'
session2_path = 'Model1 LDT RMT/ldt_session_2_data_transformed.csv'
dataset_name_override = "LDT Model 1" # Optional: Or set to None to use automatic naming

# Analysis parameters
feature = 'alpha_s1'
target = 'alpha_s2'
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
n_permutations = 1000 # Lower for faster notebook execution, increase for final results (e.g., 5000)

# --- Load and Prepare Data ---
try:
    df_merged = load_and_merge(session1_path, session2_path)
    print(f"Data loaded successfully. Number of participants: {len(df_merged)}")

    # --- Initialize Analyzer ---
    analyzer = KSGMutualInformationAnalyzer(df_merged)

    # Determine dataset name
    dataset_name = dataset_name_override
    if dataset_name is None:
        dataset_name = analyzer.get_dataset_name(session1_path)
    print(f"Analyzing dataset: {dataset_name}")

    # --- Run Analysis ---
    results = {}
    individual_results = {}

    # Calculate data-driven k value
    k_data_driven = int(np.sqrt(len(df_merged)))
    print(f"\nData-driven k value (sqrt(N)): {k_data_driven}")

    # Define k values to test (including data-driven k)
    k_values = [3, 5, 7, 10, k_data_driven]
    k_values = sorted(list(set(k_values))) # Remove duplicates and sort
    print(f"Testing k values: {k_values}")

    # Run analysis for each k
    for k in k_values:
        print(f"\nAnalyzing with k={k}...")
        # Reliability analysis (Raw MI, CMI All/Thresh/NDT)
        results[k] = analyzer.analyze_alpha_reliability(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )

        # Individual parameter analysis (CMI for each control var)
        individual_results[k] = analyzer.analyze_individual_parameters(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )
    print("\nAnalysis complete.")

    # --- Display Summary Table ---
    print("\n" + "="*80)
    print("Summary Table")
    print("="*80)
    summary_data = []
    for k in k_values:
        res_k = results[k]
        row = {
            'k': k,
            'Raw MI (bits)': f"{res_k['ksg_mi'][0]:.3f}",
            'p (Raw MI)': f"{res_k['ksg_mi'][1]:.4f}",
            'CMI All (bits)': f"{res_k.get('cond_mi_all', np.nan):.3f}",
            'p (All)': f"{res_k.get('p_value_all', np.nan):.4f}",
            'Ret All (%)': f"{res_k.get('retention_all', np.nan):.1f}",
            'CMI Thresh (bits)': f"{res_k.get('cond_mi_thresh', np.nan):.3f}",
            'p (Thresh)': f"{res_k.get('p_value_thresh', np.nan):.4f}",
            'Ret Thresh (%)': f"{res_k.get('retention_thresh', np.nan):.1f}",
            'CMI NDT (bits)': f"{res_k.get('cond_mi_ndt', np.nan):.3f}",
            'p (NDT)': f"{res_k.get('p_value_ndt', np.nan):.4f}",
            'Ret NDT (%)': f"{res_k.get('retention_ndt', np.nan):.1f}",
        }
        summary_data.append(row)

    df_summary = pd.DataFrame(summary_data)

   
    # --- ADD THIS LINE TO SAVE CSV ---
    csv_save_path = f"summary_results_{dataset_name.replace(' ', '_')}.csv"
    df_summary.to_csv(csv_save_path, index=False)
    print(f"Summary table saved to: {csv_save_path}")

    display(HTML(df_summary.to_html(index=False, na_rep='NaN')))


    # --- Generate Plots Inline by Calling Class Methods ---
    print("\n" + "="*80)
    print("Generating Plots (calling methods from KSG_MI_First.py)")
    print("="*80)

    # Call the main results plotting method
    # Pass one result dict for single point info, and all results for line plots
    analyzer.plot_results(
        results=results[k_values[-1]], # Pass results for one k (e.g., last one)
        all_k_results=results,
        feature=feature,
        target=target,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    # Call the individual parameter plotting method
    analyzer.plot_individual_parameter_effects(
        all_k_results=individual_results, # Pass the individual results dict
        feature=feature,
        target=target,
        control_vars=control_vars,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    print("\nPlot generation finished. Plots should appear above.")


    # --- Print Comprehensive Text Results ---
    print("\n" + "="*80)
    print("Comprehensive Text Results")
    print("="*80)
    for k in k_values:
        print(f"\n--- Results for k={k} {'(Data-driven)' if k == k_data_driven else ''} ---")
        res_k = results[k]
        res_indiv_k = individual_results[k]

        # Raw MI
        print(f"Raw MI: {res_k['ksg_mi'][0]:.4f} bits (p={res_k['ksg_mi'][1]:.4f})")

        # Grouped CMI
        if 'cond_mi_all' in res_k:
            print(f"CMI (All Controls): {res_k['cond_mi_all']:.4f} bits (p={res_k['p_value_all']:.4f}), Retention: {res_k['retention_all']:.1f}%")
        if 'cond_mi_thresh' in res_k:
            print(f"CMI (Threshold Only): {res_k['cond_mi_thresh']:.4f} bits (p={res_k['p_value_thresh']:.4f}), Retention: {res_k['retention_thresh']:.1f}%")
        if 'cond_mi_ndt' in res_k:
            print(f"CMI (NDT Only): {res_k['cond_mi_ndt']:.4f} bits (p={res_k['p_value_ndt']:.4f}), Retention: {res_k['retention_ndt']:.1f}%")

        # Individual CMI
        print("\nIndividual Parameter Effects:")
        for var in control_vars:
            if var in res_indiv_k:
                indiv_res = res_indiv_k[var]
                print(f"  {var}: CMI={indiv_res['cmi']:.4f} bits (p={indiv_res['p_value']:.4f}), Retention={indiv_res['retention']:.1f}%")
            else:
                print(f"  {var}: Not calculated")


except FileNotFoundError:
    print(f"Error: One or both input files not found.")
    print(f"Checked paths: '{session1_path}', '{session2_path}'")
    print("Please ensure the file paths at the top of the cell are correct.")
except ImportError:
     # Error message already printed in the import block
     pass
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    import traceback
    traceback.print_exc()
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Available columns in session 1: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s1', 'ndt_mean_s1', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s2', 'ndt_mean_s2', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: ID
# Data loaded successfully. Number of participants: 104
# Analyzing dataset: LDT Model 1
#
# Data-driven k value (sqrt(N)): 10
# Testing k values: [3, 5, 7, 10]
#
# Analyzing with k=3...
#
# Analyzing with k=5...
#
# Analyzing with k=7...
#
# Analyzing with k=10...
#
# Analysis complete.
#
# ================================================================================
# Summary Table
# ================================================================================
# Summary table saved to: summary_results_LDT_Model_1.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>k</th>
#       <th>Raw MI (bits)</th>
#       <th>p (Raw MI)</th>
#       <th>CMI All (bits)</th>
#       <th>p (All)</th>
#       <th>Ret All (%)</th>
#       <th>CMI Thresh (bits)</th>
#       <th>p (Thresh)</th>
#       <th>Ret Thresh (%)</th>
#       <th>CMI NDT (bits)</th>
#       <th>p (NDT)</th>
#       <th>Ret NDT (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>0.628</td>
#       <td>0.0010</td>
#       <td>0.196</td>
#       <td>0.0020</td>
#       <td>31.3</td>
#       <td>0.344</td>
#       <td>0.0010</td>
#       <td>54.7</td>
#       <td>0.165</td>
#       <td>0.0060</td>
#       <td>26.3</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.638</td>
#       <td>0.0010</td>
#       <td>0.047</td>
#       <td>0.0030</td>
#       <td>7.3</td>
#       <td>0.299</td>
#       <td>0.0010</td>
#       <td>46.8</td>
#       <td>0.368</td>
#       <td>0.0010</td>
#       <td>57.6</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.540</td>
#       <td>0.0010</td>
#       <td>0.012</td>
#       <td>0.0010</td>
#       <td>2.3</td>
#       <td>0.187</td>
#       <td>0.0010</td>
#       <td>34.7</td>
#       <td>0.345</td>
#       <td>0.0010</td>
#       <td>63.8</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.477</td>
#       <td>0.0010</td>
#       <td>0.004</td>
#       <td>0.0020</td>
#       <td>0.9</td>
#       <td>0.186</td>
#       <td>0.0010</td>
#       <td>38.9</td>
#       <td>0.292</td>
#       <td>0.0010</td>
#       <td>61.1</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# Generating Plots (calling methods from KSG_MI_First.py)
# ================================================================================
# Plot generation finished. Plots should appear above.
#
# ================================================================================
# Comprehensive Text Results
# ================================================================================
#
# --- Results for k=3  ---
# Raw MI: 0.6281 bits (p=0.0010)
# CMI (All Controls): 0.1964 bits (p=0.0020), Retention: 31.3%
# CMI (Threshold Only): 0.3436 bits (p=0.0010), Retention: 54.7%
# CMI (NDT Only): 0.1652 bits (p=0.0060), Retention: 26.3%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.3226 bits (p=0.0030), Retention=51.4%
#   a_mean_s2: CMI=0.4127 bits (p=0.0020), Retention=65.7%
#   ndt_mean_s1: CMI=0.4096 bits (p=0.0020), Retention=65.2%
#   ndt_mean_s2: CMI=0.4851 bits (p=0.0010), Retention=77.2%
#
# --- Results for k=5  ---
# Raw MI: 0.6382 bits (p=0.0010)
# CMI (All Controls): 0.0467 bits (p=0.0030), Retention: 7.3%
# CMI (Threshold Only): 0.2988 bits (p=0.0010), Retention: 46.8%
# CMI (NDT Only): 0.3679 bits (p=0.0010), Retention: 57.6%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.3969 bits (p=0.0010), Retention=62.2%
#   a_mean_s2: CMI=0.2592 bits (p=0.0020), Retention=40.6%
#   ndt_mean_s1: CMI=0.4244 bits (p=0.0010), Retention=66.5%
#   ndt_mean_s2: CMI=0.3833 bits (p=0.0010), Retention=60.1%
#
# --- Results for k=7  ---
# Raw MI: 0.5403 bits (p=0.0010)
# CMI (All Controls): 0.0122 bits (p=0.0010), Retention: 2.3%
# CMI (Threshold Only): 0.1873 bits (p=0.0010), Retention: 34.7%
# CMI (NDT Only): 0.3448 bits (p=0.0010), Retention: 63.8%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.3898 bits (p=0.0010), Retention=72.1%
#   a_mean_s2: CMI=0.3009 bits (p=0.0010), Retention=55.7%
#   ndt_mean_s1: CMI=0.2959 bits (p=0.0010), Retention=54.8%
#   ndt_mean_s2: CMI=0.3911 bits (p=0.0010), Retention=72.4%
#
# --- Results for k=10 (Data-driven) ---
# Raw MI: 0.4771 bits (p=0.0010)
# CMI (All Controls): 0.0044 bits (p=0.0020), Retention: 0.9%
# CMI (Threshold Only): 0.1856 bits (p=0.0010), Retention: 38.9%
# CMI (NDT Only): 0.2917 bits (p=0.0010), Retention: 61.1%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.2257 bits (p=0.0010), Retention=47.3%
#   a_mean_s2: CMI=0.2767 bits (p=0.0010), Retention=58.0%
#   ndt_mean_s1: CMI=0.2888 bits (p=0.0010), Retention=60.5%
#   ndt_mean_s2: CMI=0.3866 bits (p=0.0010), Retention=81.0%

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from IPython.display import display, HTML

# --- Import from your script ---
# Make sure KSG_MI_First.py is in the same directory or accessible
try:
    # We might need to reload the module if it was changed since the kernel started
    import importlib
    import KSG_MI_First
    importlib.reload(KSG_MI_First) # Reload to get the changes with plt.show()
    from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge
except ImportError:
    print("Error: Could not import from KSG_MI_First.py.")
    print("Make sure the file is in the same directory as the notebook or in the Python path.")
    # You might need to add the directory to the path if it's elsewhere:
    # import sys
    # sys.path.append('/path/to/your/script/directory')
    # from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge

# --- Configuration ---
# <<< IMPORTANT: UPDATE THESE PATHS >>>
session1_path = 'Model2 LDT RMT/EZ_recognition_memory_part1_transformed.csv'
session2_path = 'Model2 LDT RMT/EZ_recognition_memory_part2_transformed.csv'

dataset_name_override = "RMT Model 2" # Optional: Or set to None to use automatic naming

# Analysis parameters
feature = 'alpha_s1'
target = 'alpha_s2'
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
n_permutations = 1000 # Lower for faster notebook execution, increase for final results (e.g., 5000)

# --- Load and Prepare Data ---
try:
    df_merged = load_and_merge(session1_path, session2_path)
    print(f"Data loaded successfully. Number of participants: {len(df_merged)}")

    # --- Initialize Analyzer ---
    analyzer = KSGMutualInformationAnalyzer(df_merged)

    # Determine dataset name
    dataset_name = dataset_name_override
    if dataset_name is None:
        dataset_name = analyzer.get_dataset_name(session1_path)
    print(f"Analyzing dataset: {dataset_name}")

    # --- Run Analysis ---
    results = {}
    individual_results = {}

    # Calculate data-driven k value
    k_data_driven = int(np.sqrt(len(df_merged)))
    print(f"\nData-driven k value (sqrt(N)): {k_data_driven}")

    # Define k values to test (including data-driven k)
    k_values = [3, 5, 7, 10, k_data_driven]
    k_values = sorted(list(set(k_values))) # Remove duplicates and sort
    print(f"Testing k values: {k_values}")

    # Run analysis for each k
    for k in k_values:
        print(f"\nAnalyzing with k={k}...")
        # Reliability analysis (Raw MI, CMI All/Thresh/NDT)
        results[k] = analyzer.analyze_alpha_reliability(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )

        # Individual parameter analysis (CMI for each control var)
        individual_results[k] = analyzer.analyze_individual_parameters(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )
    print("\nAnalysis complete.")

    # --- Display Summary Table ---
    print("\n" + "="*80)
    print("Summary Table")
    print("="*80)
    summary_data = []
    for k in k_values:
        res_k = results[k]
        row = {
            'k': k,
            'Raw MI (bits)': f"{res_k['ksg_mi'][0]:.3f}",
            'p (Raw MI)': f"{res_k['ksg_mi'][1]:.4f}",
            'CMI All (bits)': f"{res_k.get('cond_mi_all', np.nan):.3f}",
            'p (All)': f"{res_k.get('p_value_all', np.nan):.4f}",
            'Ret All (%)': f"{res_k.get('retention_all', np.nan):.1f}",
            'CMI Thresh (bits)': f"{res_k.get('cond_mi_thresh', np.nan):.3f}",
            'p (Thresh)': f"{res_k.get('p_value_thresh', np.nan):.4f}",
            'Ret Thresh (%)': f"{res_k.get('retention_thresh', np.nan):.1f}",
            'CMI NDT (bits)': f"{res_k.get('cond_mi_ndt', np.nan):.3f}",
            'p (NDT)': f"{res_k.get('p_value_ndt', np.nan):.4f}",
            'Ret NDT (%)': f"{res_k.get('retention_ndt', np.nan):.1f}",
        }
        summary_data.append(row)

    df_summary = pd.DataFrame(summary_data)

   
    # --- ADD THIS LINE TO SAVE CSV ---
    csv_save_path = f"summary_results_{dataset_name.replace(' ', '_')}.csv"
    df_summary.to_csv(csv_save_path, index=False)
    print(f"Summary table saved to: {csv_save_path}")

    display(HTML(df_summary.to_html(index=False, na_rep='NaN')))


    # --- Generate Plots Inline by Calling Class Methods ---
    print("\n" + "="*80)
    print("Generating Plots (calling methods from KSG_MI_First.py)")
    print("="*80)

    # Call the main results plotting method
    # Pass one result dict for single point info, and all results for line plots
    analyzer.plot_results(
        results=results[k_values[-1]], # Pass results for one k (e.g., last one)
        all_k_results=results,
        feature=feature,
        target=target,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    # Call the individual parameter plotting method
    analyzer.plot_individual_parameter_effects(
        all_k_results=individual_results, # Pass the individual results dict
        feature=feature,
        target=target,
        control_vars=control_vars,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    print("\nPlot generation finished. Plots should appear above.")


    # --- Print Comprehensive Text Results ---
    print("\n" + "="*80)
    print("Comprehensive Text Results")
    print("="*80)
    for k in k_values:
        print(f"\n--- Results for k={k} {'(Data-driven)' if k == k_data_driven else ''} ---")
        res_k = results[k]
        res_indiv_k = individual_results[k]

        # Raw MI
        print(f"Raw MI: {res_k['ksg_mi'][0]:.4f} bits (p={res_k['ksg_mi'][1]:.4f})")

        # Grouped CMI
        if 'cond_mi_all' in res_k:
            print(f"CMI (All Controls): {res_k['cond_mi_all']:.4f} bits (p={res_k['p_value_all']:.4f}), Retention: {res_k['retention_all']:.1f}%")
        if 'cond_mi_thresh' in res_k:
            print(f"CMI (Threshold Only): {res_k['cond_mi_thresh']:.4f} bits (p={res_k['p_value_thresh']:.4f}), Retention: {res_k['retention_thresh']:.1f}%")
        if 'cond_mi_ndt' in res_k:
            print(f"CMI (NDT Only): {res_k['cond_mi_ndt']:.4f} bits (p={res_k['p_value_ndt']:.4f}), Retention: {res_k['retention_ndt']:.1f}%")

        # Individual CMI
        print("\nIndividual Parameter Effects:")
        for var in control_vars:
            if var in res_indiv_k:
                indiv_res = res_indiv_k[var]
                print(f"  {var}: CMI={indiv_res['cmi']:.4f} bits (p={indiv_res['p_value']:.4f}), Retention={indiv_res['retention']:.1f}%")
            else:
                print(f"  {var}: Not calculated")


except FileNotFoundError:
    print(f"Error: One or both input files not found.")
    print(f"Checked paths: '{session1_path}', '{session2_path}'")
    print("Please ensure the file paths at the top of the cell are correct.")
except ImportError:
     # Error message already printed in the import block
     pass
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    import traceback
    traceback.print_exc()
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Available columns in session 1: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s1', 'ndt_mean_s1', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s2', 'ndt_mean_s2', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: participant_ID
# Shape before dropping NaNs in essential columns: (103, 55)
# Shape after dropping NaNs in essential columns: (103, 55)
# Data loaded successfully. Number of participants: 103
# Analyzing dataset: RMT Model 2
#
# Data-driven k value (sqrt(N)): 10
# Testing k values: [3, 5, 7, 10]
#
# Analyzing with k=3...
#
# Analyzing with k=5...
#
# Analyzing with k=7...
#
# Analyzing with k=10...
#
# Analysis complete.
#
# ================================================================================
# Summary Table
# ================================================================================
# Summary table saved to: summary_results_RMT_Model_2.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>k</th>
#       <th>Raw MI (bits)</th>
#       <th>p (Raw MI)</th>
#       <th>CMI All (bits)</th>
#       <th>p (All)</th>
#       <th>Ret All (%)</th>
#       <th>CMI Thresh (bits)</th>
#       <th>p (Thresh)</th>
#       <th>Ret Thresh (%)</th>
#       <th>CMI NDT (bits)</th>
#       <th>p (NDT)</th>
#       <th>Ret NDT (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>0.340</td>
#       <td>0.0120</td>
#       <td>0.082</td>
#       <td>0.1389</td>
#       <td>24.2</td>
#       <td>-0.083</td>
#       <td>0.3706</td>
#       <td>-24.3</td>
#       <td>0.323</td>
#       <td>0.0010</td>
#       <td>94.8</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.307</td>
#       <td>0.0060</td>
#       <td>0.177</td>
#       <td>0.0010</td>
#       <td>57.5</td>
#       <td>0.050</td>
#       <td>0.0280</td>
#       <td>16.4</td>
#       <td>0.240</td>
#       <td>0.0020</td>
#       <td>78.1</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.196</td>
#       <td>0.0150</td>
#       <td>0.129</td>
#       <td>0.0010</td>
#       <td>65.8</td>
#       <td>0.090</td>
#       <td>0.0040</td>
#       <td>45.7</td>
#       <td>0.227</td>
#       <td>0.0010</td>
#       <td>115.7</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.194</td>
#       <td>0.0060</td>
#       <td>0.131</td>
#       <td>0.0010</td>
#       <td>67.5</td>
#       <td>0.049</td>
#       <td>0.0020</td>
#       <td>25.5</td>
#       <td>0.250</td>
#       <td>0.0010</td>
#       <td>129.0</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# Generating Plots (calling methods from KSG_MI_First.py)
# ================================================================================
# Plot generation finished. Plots should appear above.
#
# ================================================================================
# Comprehensive Text Results
# ================================================================================
#
# --- Results for k=3  ---
# Raw MI: 0.3403 bits (p=0.0120)
# CMI (All Controls): 0.0824 bits (p=0.1389), Retention: 24.2%
# CMI (Threshold Only): -0.0826 bits (p=0.3706), Retention: -24.3%
# CMI (NDT Only): 0.3228 bits (p=0.0010), Retention: 94.8%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.2442 bits (p=0.2198), Retention=71.8%
#   a_mean_s2: CMI=-0.0943 bits (p=0.1738), Retention=-27.7%
#   ndt_mean_s1: CMI=0.4142 bits (p=0.0010), Retention=121.7%
#   ndt_mean_s2: CMI=0.2439 bits (p=0.0030), Retention=71.7%
#
# --- Results for k=5  ---
# Raw MI: 0.3072 bits (p=0.0060)
# CMI (All Controls): 0.1767 bits (p=0.0010), Retention: 57.5%
# CMI (Threshold Only): 0.0503 bits (p=0.0280), Retention: 16.4%
# CMI (NDT Only): 0.2399 bits (p=0.0020), Retention: 78.1%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.2377 bits (p=0.0190), Retention=77.4%
#   a_mean_s2: CMI=0.0076 bits (p=0.2637), Retention=2.5%
#   ndt_mean_s1: CMI=0.1882 bits (p=0.0010), Retention=61.3%
#   ndt_mean_s2: CMI=0.2936 bits (p=0.0010), Retention=95.6%
#
# --- Results for k=7  ---
# Raw MI: 0.1962 bits (p=0.0150)
# CMI (All Controls): 0.1291 bits (p=0.0010), Retention: 65.8%
# CMI (Threshold Only): 0.0896 bits (p=0.0040), Retention: 45.7%
# CMI (NDT Only): 0.2269 bits (p=0.0010), Retention: 115.7%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.1630 bits (p=0.0050), Retention=83.1%
#   a_mean_s2: CMI=0.0542 bits (p=0.0240), Retention=27.6%
#   ndt_mean_s1: CMI=0.2025 bits (p=0.0010), Retention=103.3%
#   ndt_mean_s2: CMI=0.2254 bits (p=0.0040), Retention=114.9%
#
# --- Results for k=10 (Data-driven) ---
# Raw MI: 0.1935 bits (p=0.0060)
# CMI (All Controls): 0.1306 bits (p=0.0010), Retention: 67.5%
# CMI (Threshold Only): 0.0494 bits (p=0.0020), Retention: 25.5%
# CMI (NDT Only): 0.2497 bits (p=0.0010), Retention: 129.0%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.1718 bits (p=0.0010), Retention=88.8%
#   a_mean_s2: CMI=0.0712 bits (p=0.0170), Retention=36.8%
#   ndt_mean_s1: CMI=0.2289 bits (p=0.0010), Retention=118.3%
#   ndt_mean_s2: CMI=0.1670 bits (p=0.0010), Retention=86.3%

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from IPython.display import display, HTML

# --- Import from your script ---
# Make sure KSG_MI_First.py is in the same directory or accessible
try:
    # We might need to reload the module if it was changed since the kernel started
    import importlib
    import KSG_MI_First
    importlib.reload(KSG_MI_First) # Reload to get the changes with plt.show()
    from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge
except ImportError:
    print("Error: Could not import from KSG_MI_First.py.")
    print("Make sure the file is in the same directory as the notebook or in the Python path.")
    # You might need to add the directory to the path if it's elsewhere:
    # import sys
    # sys.path.append('/path/to/your/script/directory')
    # from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge

# --- Configuration ---
# <<< IMPORTANT: UPDATE THESE PATHS >>>
session1_path = 'Model1 LDT RMT/rmt_session_1_data_transformed.csv'
session2_path = 'Model1 LDT RMT/rmt_session_2_data_transformed.csv'

dataset_name_override = "RMT Model 1" # Optional: Or set to None to use automatic naming

# Analysis parameters
feature = 'alpha_s1'
target = 'alpha_s2'
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
n_permutations = 1000 # Lower for faster notebook execution, increase for final results (e.g., 5000)

# --- Load and Prepare Data ---
try:
    df_merged = load_and_merge(session1_path, session2_path)
    print(f"Data loaded successfully. Number of participants: {len(df_merged)}")

    # --- Initialize Analyzer ---
    analyzer = KSGMutualInformationAnalyzer(df_merged)

    # Determine dataset name
    dataset_name = dataset_name_override
    if dataset_name is None:
        dataset_name = analyzer.get_dataset_name(session1_path)
    print(f"Analyzing dataset: {dataset_name}")

    # --- Run Analysis ---
    results = {}
    individual_results = {}

    # Calculate data-driven k value
    k_data_driven = int(np.sqrt(len(df_merged)))
    print(f"\nData-driven k value (sqrt(N)): {k_data_driven}")

    # Define k values to test (including data-driven k)
    k_values = [3, 5, 7, 10, k_data_driven]
    k_values = sorted(list(set(k_values))) # Remove duplicates and sort
    print(f"Testing k values: {k_values}")

    # Run analysis for each k
    for k in k_values:
        print(f"\nAnalyzing with k={k}...")
        # Reliability analysis (Raw MI, CMI All/Thresh/NDT)
        results[k] = analyzer.analyze_alpha_reliability(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )

        # Individual parameter analysis (CMI for each control var)
        individual_results[k] = analyzer.analyze_individual_parameters(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )
    print("\nAnalysis complete.")

    # --- Display Summary Table ---
    print("\n" + "="*80)
    print("Summary Table")
    print("="*80)
    summary_data = []
    for k in k_values:
        res_k = results[k]
        row = {
            'k': k,
            'Raw MI (bits)': f"{res_k['ksg_mi'][0]:.3f}",
            'p (Raw MI)': f"{res_k['ksg_mi'][1]:.4f}",
            'CMI All (bits)': f"{res_k.get('cond_mi_all', np.nan):.3f}",
            'p (All)': f"{res_k.get('p_value_all', np.nan):.4f}",
            'Ret All (%)': f"{res_k.get('retention_all', np.nan):.1f}",
            'CMI Thresh (bits)': f"{res_k.get('cond_mi_thresh', np.nan):.3f}",
            'p (Thresh)': f"{res_k.get('p_value_thresh', np.nan):.4f}",
            'Ret Thresh (%)': f"{res_k.get('retention_thresh', np.nan):.1f}",
            'CMI NDT (bits)': f"{res_k.get('cond_mi_ndt', np.nan):.3f}",
            'p (NDT)': f"{res_k.get('p_value_ndt', np.nan):.4f}",
            'Ret NDT (%)': f"{res_k.get('retention_ndt', np.nan):.1f}",
        }
        summary_data.append(row)

    df_summary = pd.DataFrame(summary_data)

   
    # --- ADD THIS LINE TO SAVE CSV ---
    csv_save_path = f"summary_results_{dataset_name.replace(' ', '_')}.csv"
    df_summary.to_csv(csv_save_path, index=False)
    print(f"Summary table saved to: {csv_save_path}")

    display(HTML(df_summary.to_html(index=False, na_rep='NaN')))


    # --- Generate Plots Inline by Calling Class Methods ---
    print("\n" + "="*80)
    print("Generating Plots (calling methods from KSG_MI_First.py)")
    print("="*80)

    # Call the main results plotting method
    # Pass one result dict for single point info, and all results for line plots
    analyzer.plot_results(
        results=results[k_values[-1]], # Pass results for one k (e.g., last one)
        all_k_results=results,
        feature=feature,
        target=target,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    # Call the individual parameter plotting method
    analyzer.plot_individual_parameter_effects(
        all_k_results=individual_results, # Pass the individual results dict
        feature=feature,
        target=target,
        control_vars=control_vars,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    print("\nPlot generation finished. Plots should appear above.")


    # --- Print Comprehensive Text Results ---
    print("\n" + "="*80)
    print("Comprehensive Text Results")
    print("="*80)
    for k in k_values:
        print(f"\n--- Results for k={k} {'(Data-driven)' if k == k_data_driven else ''} ---")
        res_k = results[k]
        res_indiv_k = individual_results[k]

        # Raw MI
        print(f"Raw MI: {res_k['ksg_mi'][0]:.4f} bits (p={res_k['ksg_mi'][1]:.4f})")

        # Grouped CMI
        if 'cond_mi_all' in res_k:
            print(f"CMI (All Controls): {res_k['cond_mi_all']:.4f} bits (p={res_k['p_value_all']:.4f}), Retention: {res_k['retention_all']:.1f}%")
        if 'cond_mi_thresh' in res_k:
            print(f"CMI (Threshold Only): {res_k['cond_mi_thresh']:.4f} bits (p={res_k['p_value_thresh']:.4f}), Retention: {res_k['retention_thresh']:.1f}%")
        if 'cond_mi_ndt' in res_k:
            print(f"CMI (NDT Only): {res_k['cond_mi_ndt']:.4f} bits (p={res_k['p_value_ndt']:.4f}), Retention: {res_k['retention_ndt']:.1f}%")

        # Individual CMI
        print("\nIndividual Parameter Effects:")
        for var in control_vars:
            if var in res_indiv_k:
                indiv_res = res_indiv_k[var]
                print(f"  {var}: CMI={indiv_res['cmi']:.4f} bits (p={indiv_res['p_value']:.4f}), Retention={indiv_res['retention']:.1f}%")
            else:
                print(f"  {var}: Not calculated")


except FileNotFoundError:
    print(f"Error: One or both input files not found.")
    print(f"Checked paths: '{session1_path}', '{session2_path}'")
    print("Please ensure the file paths at the top of the cell are correct.")
except ImportError:
     # Error message already printed in the import block
     pass
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Available columns in session 1: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s1', 'ndt_mean_s1', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s2', 'ndt_mean_s2', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: ID
# Shape before dropping NaNs in essential columns: (103, 51)
# Shape after dropping NaNs in essential columns: (103, 51)
# Data loaded successfully. Number of participants: 103
# Analyzing dataset: RMT Model 1
#
# Data-driven k value (sqrt(N)): 10
# Testing k values: [3, 5, 7, 10]
#
# Analyzing with k=3...
#
# Analyzing with k=5...
#
# Analyzing with k=7...
#
# Analyzing with k=10...
#
# Analysis complete.
#
# ================================================================================
# Summary Table
# ================================================================================
# Summary table saved to: summary_results_RMT_Model_1.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>k</th>
#       <th>Raw MI (bits)</th>
#       <th>p (Raw MI)</th>
#       <th>CMI All (bits)</th>
#       <th>p (All)</th>
#       <th>Ret All (%)</th>
#       <th>CMI Thresh (bits)</th>
#       <th>p (Thresh)</th>
#       <th>Ret Thresh (%)</th>
#       <th>CMI NDT (bits)</th>
#       <th>p (NDT)</th>
#       <th>Ret NDT (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>0.100</td>
#       <td>0.2078</td>
#       <td>-0.270</td>
#       <td>1.0000</td>
#       <td>-269.7</td>
#       <td>-0.024</td>
#       <td>0.5504</td>
#       <td>-24.4</td>
#       <td>-0.051</td>
#       <td>0.3337</td>
#       <td>-51.4</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.041</td>
#       <td>0.3187</td>
#       <td>-0.060</td>
#       <td>0.9950</td>
#       <td>-147.4</td>
#       <td>0.014</td>
#       <td>0.5405</td>
#       <td>35.1</td>
#       <td>-0.053</td>
#       <td>0.6803</td>
#       <td>-129.2</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.093</td>
#       <td>0.1139</td>
#       <td>-0.049</td>
#       <td>0.9920</td>
#       <td>-52.7</td>
#       <td>-0.043</td>
#       <td>0.6334</td>
#       <td>-46.8</td>
#       <td>-0.112</td>
#       <td>0.8262</td>
#       <td>-121.3</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.117</td>
#       <td>0.0400</td>
#       <td>-0.034</td>
#       <td>0.8392</td>
#       <td>-29.3</td>
#       <td>-0.051</td>
#       <td>0.6354</td>
#       <td>-43.7</td>
#       <td>-0.012</td>
#       <td>0.7213</td>
#       <td>-10.1</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# Generating Plots (calling methods from KSG_MI_First.py)
# ================================================================================
# Plot generation finished. Plots should appear above.
#
# ================================================================================
# Comprehensive Text Results
# ================================================================================
#
# --- Results for k=3  ---
# Raw MI: 0.1002 bits (p=0.2078)
# CMI (All Controls): -0.2703 bits (p=1.0000), Retention: -269.7%
# CMI (Threshold Only): -0.0245 bits (p=0.5504), Retention: -24.4%
# CMI (NDT Only): -0.0515 bits (p=0.3337), Retention: -51.4%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.0526 bits (p=0.1568), Retention=52.5%
#   a_mean_s2: CMI=0.1922 bits (p=0.0609), Retention=191.8%
#   ndt_mean_s1: CMI=0.0637 bits (p=0.3636), Retention=63.6%
#   ndt_mean_s2: CMI=0.1197 bits (p=0.2328), Retention=119.5%
#
# --- Results for k=5  ---
# Raw MI: 0.0409 bits (p=0.3187)
# CMI (All Controls): -0.0603 bits (p=0.9950), Retention: -147.4%
# CMI (Threshold Only): 0.0143 bits (p=0.5405), Retention: 35.1%
# CMI (NDT Only): -0.0528 bits (p=0.6803), Retention: -129.2%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.1295 bits (p=0.1119), Retention=316.6%
#   a_mean_s2: CMI=0.0529 bits (p=0.3886), Retention=129.4%
#   ndt_mean_s1: CMI=0.0948 bits (p=0.0460), Retention=231.7%
#   ndt_mean_s2: CMI=-0.0130 bits (p=0.1349), Retention=-31.9%
#
# --- Results for k=7  ---
# Raw MI: 0.0927 bits (p=0.1139)
# CMI (All Controls): -0.0488 bits (p=0.9920), Retention: -52.7%
# CMI (Threshold Only): -0.0434 bits (p=0.6334), Retention: -46.8%
# CMI (NDT Only): -0.1125 bits (p=0.8262), Retention: -121.3%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.0664 bits (p=0.3896), Retention=71.6%
#   a_mean_s2: CMI=0.0589 bits (p=0.2228), Retention=63.6%
#   ndt_mean_s1: CMI=0.0907 bits (p=0.1668), Retention=97.9%
#   ndt_mean_s2: CMI=-0.0554 bits (p=0.2977), Retention=-59.8%
#
# --- Results for k=10 (Data-driven) ---
# Raw MI: 0.1168 bits (p=0.0400)
# CMI (All Controls): -0.0342 bits (p=0.8392), Retention: -29.3%
# CMI (Threshold Only): -0.0511 bits (p=0.6354), Retention: -43.7%
# CMI (NDT Only): -0.0118 bits (p=0.7213), Retention: -10.1%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=-0.0219 bits (p=0.7992), Retention=-18.7%
#   a_mean_s2: CMI=0.0235 bits (p=0.3137), Retention=20.1%
#   ndt_mean_s1: CMI=0.0114 bits (p=0.2617), Retention=9.8%
#   ndt_mean_s2: CMI=0.0182 bits (p=0.1778), Retention=15.6%

# %%
RMT2=pd.read_csv("Model2 LDT RMT/EZ_recognition_memory_part1_transformed.csv")
RMT2["participant_ID"]
# Out:
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5
#        ...
# 98     4009
# 99     4010
# 100    4011
# 101    4012
# 102    4013
# Name: participant_ID, Length: 103, dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from IPython.display import display, HTML

# --- Import from your script ---
# Make sure KSG_MI_First.py is in the same directory or accessible
try:
    # We might need to reload the module if it was changed since the kernel started
    import importlib
    import KSG_MI_First
    importlib.reload(KSG_MI_First) # Reload to get the changes with plt.show()
    from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge
except ImportError:
    print("Error: Could not import from KSG_MI_First.py.")
    print("Make sure the file is in the same directory as the notebook or in the Python path.")
    # You might need to add the directory to the path if it's elsewhere:
    # import sys
    # sys.path.append('/path/to/your/script/directory')
    # from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge

# --- Configuration ---
# <<< IMPORTANT: UPDATE THESE PATHS >>>
session1_path = 'Model2 LDT RMT/EZ_lexical_decision_part1_transformed.csv'
session2_path = 'Model2 LDT RMT/EZ_lexical_decision_part2_transformed.csv'

dataset_name_override = "LDT Model 2" # Optional: Or set to None to use automatic naming

# Analysis parameters
feature = 'alpha_s1'
target = 'alpha_s2'
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
n_permutations = 1000 # Lower for faster notebook execution, increase for final results (e.g., 5000)

# --- Load and Prepare Data ---
try:
    df_merged = load_and_merge(session1_path, session2_path)
    print(f"Data loaded successfully. Number of participants: {len(df_merged)}")

    # --- Initialize Analyzer ---
    analyzer = KSGMutualInformationAnalyzer(df_merged)

    # Determine dataset name
    dataset_name = dataset_name_override
    if dataset_name is None:
        dataset_name = analyzer.get_dataset_name(session1_path)
    print(f"Analyzing dataset: {dataset_name}")

    # --- Run Analysis ---
    results = {}
    individual_results = {}

    # Calculate data-driven k value
    k_data_driven = int(np.sqrt(len(df_merged)))
    print(f"\nData-driven k value (sqrt(N)): {k_data_driven}")

    # Define k values to test (including data-driven k)
    k_values = [3, 5, 7, 10, k_data_driven]
    k_values = sorted(list(set(k_values))) # Remove duplicates and sort
    print(f"Testing k values: {k_values}")

    # Run analysis for each k
    for k in k_values:
        print(f"\nAnalyzing with k={k}...")
        # Reliability analysis (Raw MI, CMI All/Thresh/NDT)
        results[k] = analyzer.analyze_alpha_reliability(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )

        # Individual parameter analysis (CMI for each control var)
        individual_results[k] = analyzer.analyze_individual_parameters(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )
    print("\nAnalysis complete.")

    # --- Display Summary Table ---
    print("\n" + "="*80)
    print("Summary Table")
    print("="*80)
    summary_data = []
    for k in k_values:
        res_k = results[k]
        row = {
            'k': k,
            'Raw MI (bits)': f"{res_k['ksg_mi'][0]:.3f}",
            'p (Raw MI)': f"{res_k['ksg_mi'][1]:.4f}",
            'CMI All (bits)': f"{res_k.get('cond_mi_all', np.nan):.3f}",
            'p (All)': f"{res_k.get('p_value_all', np.nan):.4f}",
            'Ret All (%)': f"{res_k.get('retention_all', np.nan):.1f}",
            'CMI Thresh (bits)': f"{res_k.get('cond_mi_thresh', np.nan):.3f}",
            'p (Thresh)': f"{res_k.get('p_value_thresh', np.nan):.4f}",
            'Ret Thresh (%)': f"{res_k.get('retention_thresh', np.nan):.1f}",
            'CMI NDT (bits)': f"{res_k.get('cond_mi_ndt', np.nan):.3f}",
            'p (NDT)': f"{res_k.get('p_value_ndt', np.nan):.4f}",
            'Ret NDT (%)': f"{res_k.get('retention_ndt', np.nan):.1f}",
        }
        summary_data.append(row)

    df_summary = pd.DataFrame(summary_data)

   
    # --- ADD THIS LINE TO SAVE CSV ---
    csv_save_path = f"summary_results_{dataset_name.replace(' ', '_')}.csv"
    df_summary.to_csv(csv_save_path, index=False)
    print(f"Summary table saved to: {csv_save_path}")

    display(HTML(df_summary.to_html(index=False, na_rep='NaN')))


    # --- Generate Plots Inline by Calling Class Methods ---
    print("\n" + "="*80)
    print("Generating Plots (calling methods from KSG_MI_First.py)")
    print("="*80)

    # Call the main results plotting method
    # Pass one result dict for single point info, and all results for line plots
    analyzer.plot_results(
        results=results[k_values[-1]], # Pass results for one k (e.g., last one)
        all_k_results=results,
        feature=feature,
        target=target,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    # Call the individual parameter plotting method
    analyzer.plot_individual_parameter_effects(
        all_k_results=individual_results, # Pass the individual results dict
        feature=feature,
        target=target,
        control_vars=control_vars,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    print("\nPlot generation finished. Plots should appear above.")


    # --- Print Comprehensive Text Results ---
    print("\n" + "="*80)
    print("Comprehensive Text Results")
    print("="*80)
    for k in k_values:
        print(f"\n--- Results for k={k} {'(Data-driven)' if k == k_data_driven else ''} ---")
        res_k = results[k]
        res_indiv_k = individual_results[k]

        # Raw MI
        print(f"Raw MI: {res_k['ksg_mi'][0]:.4f} bits (p={res_k['ksg_mi'][1]:.4f})")

        # Grouped CMI
        if 'cond_mi_all' in res_k:
            print(f"CMI (All Controls): {res_k['cond_mi_all']:.4f} bits (p={res_k['p_value_all']:.4f}), Retention: {res_k['retention_all']:.1f}%")
        if 'cond_mi_thresh' in res_k:
            print(f"CMI (Threshold Only): {res_k['cond_mi_thresh']:.4f} bits (p={res_k['p_value_thresh']:.4f}), Retention: {res_k['retention_thresh']:.1f}%")
        if 'cond_mi_ndt' in res_k:
            print(f"CMI (NDT Only): {res_k['cond_mi_ndt']:.4f} bits (p={res_k['p_value_ndt']:.4f}), Retention: {res_k['retention_ndt']:.1f}%")

        # Individual CMI
        print("\nIndividual Parameter Effects:")
        for var in control_vars:
            if var in res_indiv_k:
                indiv_res = res_indiv_k[var]
                print(f"  {var}: CMI={indiv_res['cmi']:.4f} bits (p={indiv_res['p_value']:.4f}), Retention={indiv_res['retention']:.1f}%")
            else:
                print(f"  {var}: Not calculated")


except FileNotFoundError:
    print(f"Error: One or both input files not found.")
    print(f"Checked paths: '{session1_path}', '{session2_path}'")
    print("Please ensure the file paths at the top of the cell are correct.")
except ImportError:
     # Error message already printed in the import block
     pass
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Available columns in session 1: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s1', 'ndt_mean_s1', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s2', 'ndt_mean_s2', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: participant_ID
# Data loaded successfully. Number of participants: 101
# Analyzing dataset: LDT Model 2
#
# Data-driven k value (sqrt(N)): 10
# Testing k values: [3, 5, 7, 10]
#
# Analyzing with k=3...
#
# Analyzing with k=5...
#
# Analyzing with k=7...
#
# Analyzing with k=10...
#
# Analysis complete.
#
# ================================================================================
# Summary Table
# ================================================================================
# Summary table saved to: summary_results_LDT_Model_2.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>k</th>
#       <th>Raw MI (bits)</th>
#       <th>p (Raw MI)</th>
#       <th>CMI All (bits)</th>
#       <th>p (All)</th>
#       <th>Ret All (%)</th>
#       <th>CMI Thresh (bits)</th>
#       <th>p (Thresh)</th>
#       <th>Ret Thresh (%)</th>
#       <th>CMI NDT (bits)</th>
#       <th>p (NDT)</th>
#       <th>Ret NDT (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>0.582</td>
#       <td>0.0010</td>
#       <td>0.259</td>
#       <td>0.0050</td>
#       <td>44.4</td>
#       <td>0.359</td>
#       <td>0.0010</td>
#       <td>61.6</td>
#       <td>0.359</td>
#       <td>0.0010</td>
#       <td>61.6</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.563</td>
#       <td>0.0010</td>
#       <td>0.238</td>
#       <td>0.0010</td>
#       <td>42.2</td>
#       <td>0.432</td>
#       <td>0.0010</td>
#       <td>76.7</td>
#       <td>0.304</td>
#       <td>0.0010</td>
#       <td>54.0</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.510</td>
#       <td>0.0010</td>
#       <td>0.152</td>
#       <td>0.0010</td>
#       <td>29.8</td>
#       <td>0.497</td>
#       <td>0.0010</td>
#       <td>97.5</td>
#       <td>0.350</td>
#       <td>0.0010</td>
#       <td>68.7</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.601</td>
#       <td>0.0010</td>
#       <td>0.126</td>
#       <td>0.0010</td>
#       <td>20.9</td>
#       <td>0.426</td>
#       <td>0.0010</td>
#       <td>70.8</td>
#       <td>0.321</td>
#       <td>0.0010</td>
#       <td>53.4</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# Generating Plots (calling methods from KSG_MI_First.py)
# ================================================================================
# Plot generation finished. Plots should appear above.
#
# ================================================================================
# Comprehensive Text Results
# ================================================================================
#
# --- Results for k=3  ---
# Raw MI: 0.5824 bits (p=0.0010)
# CMI (All Controls): 0.2587 bits (p=0.0050), Retention: 44.4%
# CMI (Threshold Only): 0.3586 bits (p=0.0010), Retention: 61.6%
# CMI (NDT Only): 0.3587 bits (p=0.0010), Retention: 61.6%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.8002 bits (p=0.0010), Retention=137.4%
#   a_mean_s2: CMI=0.4589 bits (p=0.0010), Retention=78.8%
#   ndt_mean_s1: CMI=0.3517 bits (p=0.0010), Retention=60.4%
#   ndt_mean_s2: CMI=0.6089 bits (p=0.0010), Retention=104.5%
#
# --- Results for k=5  ---
# Raw MI: 0.5632 bits (p=0.0010)
# CMI (All Controls): 0.2377 bits (p=0.0010), Retention: 42.2%
# CMI (Threshold Only): 0.4321 bits (p=0.0010), Retention: 76.7%
# CMI (NDT Only): 0.3044 bits (p=0.0010), Retention: 54.0%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.5711 bits (p=0.0010), Retention=101.4%
#   a_mean_s2: CMI=0.3729 bits (p=0.0010), Retention=66.2%
#   ndt_mean_s1: CMI=0.3542 bits (p=0.0010), Retention=62.9%
#   ndt_mean_s2: CMI=0.4527 bits (p=0.0010), Retention=80.4%
#
# --- Results for k=7  ---
# Raw MI: 0.5100 bits (p=0.0010)
# CMI (All Controls): 0.1522 bits (p=0.0010), Retention: 29.8%
# CMI (Threshold Only): 0.4971 bits (p=0.0010), Retention: 97.5%
# CMI (NDT Only): 0.3502 bits (p=0.0010), Retention: 68.7%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.5368 bits (p=0.0010), Retention=105.2%
#   a_mean_s2: CMI=0.4153 bits (p=0.0010), Retention=81.4%
#   ndt_mean_s1: CMI=0.3808 bits (p=0.0010), Retention=74.7%
#   ndt_mean_s2: CMI=0.3590 bits (p=0.0010), Retention=70.4%
#
# --- Results for k=10 (Data-driven) ---
# Raw MI: 0.6012 bits (p=0.0010)
# CMI (All Controls): 0.1258 bits (p=0.0010), Retention: 20.9%
# CMI (Threshold Only): 0.4258 bits (p=0.0010), Retention: 70.8%
# CMI (NDT Only): 0.3213 bits (p=0.0010), Retention: 53.4%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.4679 bits (p=0.0010), Retention=77.8%
#   a_mean_s2: CMI=0.4335 bits (p=0.0010), Retention=72.1%
#   ndt_mean_s1: CMI=0.3375 bits (p=0.0010), Retention=56.1%
#   ndt_mean_s2: CMI=0.3758 bits (p=0.0010), Retention=62.5%

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from IPython.display import display, HTML

# --- Import from your script ---
# Make sure KSG_MI_First.py is in the same directory or accessible
try:
    # We might need to reload the module if it was changed since the kernel started
    import importlib
    import KSG_MI_First
    importlib.reload(KSG_MI_First) # Reload to get the changes with plt.show()
    from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge
except ImportError:
    print("Error: Could not import from KSG_MI_First.py.")
    print("Make sure the file is in the same directory as the notebook or in the Python path.")
    # You might need to add the directory to the path if it's elsewhere:
    # import sys
    # sys.path.append('/path/to/your/script/directory')
    # from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge

# --- Configuration ---
# <<< IMPORTANT: UPDATE THESE PATHS >>>
session1_path = 'Model1 ELP/Transformed_recoverd_param_ELP_S1_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'
session2_path = 'Model1 ELP/Transformed_recoverd_param_ELP_S2_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'

dataset_name_override = "ELP Model 1" # Optional: Or set to None to use automatic naming

# Analysis parameters
feature = 'alpha_s1'
target = 'alpha_s2'
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
n_permutations = 1000 # Lower for faster notebook execution, increase for final results (e.g., 5000)

# --- Load and Prepare Data ---
try:
    df_merged = load_and_merge(session1_path, session2_path)
    print(f"Data loaded successfully. Number of participants: {len(df_merged)}")

    # --- Initialize Analyzer ---
    analyzer = KSGMutualInformationAnalyzer(df_merged)

    # Determine dataset name
    dataset_name = dataset_name_override
    if dataset_name is None:
        dataset_name = analyzer.get_dataset_name(session1_path)
    print(f"Analyzing dataset: {dataset_name}")

    # --- Run Analysis ---
    results = {}
    individual_results = {}

    # Calculate data-driven k value
    k_data_driven = int(np.sqrt(len(df_merged)))
    print(f"\nData-driven k value (sqrt(N)): {k_data_driven}")

    # Define k values to test (including data-driven k)
    k_values = [3, 5, 7, 10, k_data_driven]
    k_values = sorted(list(set(k_values))) # Remove duplicates and sort
    print(f"Testing k values: {k_values}")

    # Run analysis for each k
    for k in k_values:
        print(f"\nAnalyzing with k={k}...")
        # Reliability analysis (Raw MI, CMI All/Thresh/NDT)
        results[k] = analyzer.analyze_alpha_reliability(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )

        # Individual parameter analysis (CMI for each control var)
        individual_results[k] = analyzer.analyze_individual_parameters(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )
    print("\nAnalysis complete.")

    # --- Display Summary Table ---
    print("\n" + "="*80)
    print("Summary Table")
    print("="*80)
    summary_data = []
    for k in k_values:
        res_k = results[k]
        row = {
            'k': k,
            'Raw MI (bits)': f"{res_k['ksg_mi'][0]:.3f}",
            'p (Raw MI)': f"{res_k['ksg_mi'][1]:.4f}",
            'CMI All (bits)': f"{res_k.get('cond_mi_all', np.nan):.3f}",
            'p (All)': f"{res_k.get('p_value_all', np.nan):.4f}",
            'Ret All (%)': f"{res_k.get('retention_all', np.nan):.1f}",
            'CMI Thresh (bits)': f"{res_k.get('cond_mi_thresh', np.nan):.3f}",
            'p (Thresh)': f"{res_k.get('p_value_thresh', np.nan):.4f}",
            'Ret Thresh (%)': f"{res_k.get('retention_thresh', np.nan):.1f}",
            'CMI NDT (bits)': f"{res_k.get('cond_mi_ndt', np.nan):.3f}",
            'p (NDT)': f"{res_k.get('p_value_ndt', np.nan):.4f}",
            'Ret NDT (%)': f"{res_k.get('retention_ndt', np.nan):.1f}",
        }
        summary_data.append(row)

    df_summary = pd.DataFrame(summary_data)

   
    # --- ADD THIS LINE TO SAVE CSV ---
    csv_save_path = f"summary_results_{dataset_name.replace(' ', '_')}.csv"
    df_summary.to_csv(csv_save_path, index=False)
    print(f"Summary table saved to: {csv_save_path}")

    display(HTML(df_summary.to_html(index=False, na_rep='NaN')))


    # --- Generate Plots Inline by Calling Class Methods ---
    print("\n" + "="*80)
    print("Generating Plots (calling methods from KSG_MI_First.py)")
    print("="*80)

    # Call the main results plotting method
    # Pass one result dict for single point info, and all results for line plots
    analyzer.plot_results(
        results=results[k_values[-1]], # Pass results for one k (e.g., last one)
        all_k_results=results,
        feature=feature,
        target=target,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    # Call the individual parameter plotting method
    analyzer.plot_individual_parameter_effects(
        all_k_results=individual_results, # Pass the individual results dict
        feature=feature,
        target=target,
        control_vars=control_vars,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    print("\nPlot generation finished. Plots should appear above.")


    # --- Print Comprehensive Text Results ---
    print("\n" + "="*80)
    print("Comprehensive Text Results")
    print("="*80)
    for k in k_values:
        print(f"\n--- Results for k={k} {'(Data-driven)' if k == k_data_driven else ''} ---")
        res_k = results[k]
        res_indiv_k = individual_results[k]

        # Raw MI
        print(f"Raw MI: {res_k['ksg_mi'][0]:.4f} bits (p={res_k['ksg_mi'][1]:.4f})")

        # Grouped CMI
        if 'cond_mi_all' in res_k:
            print(f"CMI (All Controls): {res_k['cond_mi_all']:.4f} bits (p={res_k['p_value_all']:.4f}), Retention: {res_k['retention_all']:.1f}%")
        if 'cond_mi_thresh' in res_k:
            print(f"CMI (Threshold Only): {res_k['cond_mi_thresh']:.4f} bits (p={res_k['p_value_thresh']:.4f}), Retention: {res_k['retention_thresh']:.1f}%")
        if 'cond_mi_ndt' in res_k:
            print(f"CMI (NDT Only): {res_k['cond_mi_ndt']:.4f} bits (p={res_k['p_value_ndt']:.4f}), Retention: {res_k['retention_ndt']:.1f}%")

        # Individual CMI
        print("\nIndividual Parameter Effects:")
        for var in control_vars:
            if var in res_indiv_k:
                indiv_res = res_indiv_k[var]
                print(f"  {var}: CMI={indiv_res['cmi']:.4f} bits (p={indiv_res['p_value']:.4f}), Retention={indiv_res['retention']:.1f}%")
            else:
                print(f"  {var}: Not calculated")


except FileNotFoundError:
    print(f"Error: One or both input files not found.")
    print(f"Checked paths: '{session1_path}', '{session2_path}'")
    print("Please ensure the file paths at the top of the cell are correct.")
except ImportError:
     # Error message already printed in the import block
     pass
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Available columns in session 1: ['Unnamed: 0', 'participant', 'v1', 'v2', 'zr', 'a_mean_s1', 'ndt_mean_s1', 'sndt', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'participant', 'v1', 'v2', 'zr', 'a_mean_s2', 'ndt_mean_s2', 'sndt', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Using identifier column: participant
# Shape before dropping NaNs in essential columns: (806, 47)
# Shape after dropping NaNs in essential columns: (806, 47)
# Data loaded successfully. Number of participants: 806
# Analyzing dataset: ELP Model 1
#
# Data-driven k value (sqrt(N)): 28
# Testing k values: [3, 5, 7, 10, 28]
#
# Analyzing with k=3...
#
# Analyzing with k=5...
#
# Analyzing with k=7...
#
# Analyzing with k=10...
#
# Analyzing with k=28...
#
# Analysis complete.
#
# ================================================================================
# Summary Table
# ================================================================================
# Summary table saved to: summary_results_ELP_Model_1.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>k</th>
#       <th>Raw MI (bits)</th>
#       <th>p (Raw MI)</th>
#       <th>CMI All (bits)</th>
#       <th>p (All)</th>
#       <th>Ret All (%)</th>
#       <th>CMI Thresh (bits)</th>
#       <th>p (Thresh)</th>
#       <th>Ret Thresh (%)</th>
#       <th>CMI NDT (bits)</th>
#       <th>p (NDT)</th>
#       <th>Ret NDT (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>3</td>
#       <td>0.579</td>
#       <td>0.0010</td>
#       <td>0.335</td>
#       <td>0.0010</td>
#       <td>57.8</td>
#       <td>0.465</td>
#       <td>0.0010</td>
#       <td>80.3</td>
#       <td>0.593</td>
#       <td>0.0010</td>
#       <td>102.5</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.591</td>
#       <td>0.0010</td>
#       <td>0.294</td>
#       <td>0.0010</td>
#       <td>49.8</td>
#       <td>0.441</td>
#       <td>0.0010</td>
#       <td>74.7</td>
#       <td>0.585</td>
#       <td>0.0010</td>
#       <td>99.0</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.598</td>
#       <td>0.0010</td>
#       <td>0.266</td>
#       <td>0.0010</td>
#       <td>44.4</td>
#       <td>0.429</td>
#       <td>0.0010</td>
#       <td>71.7</td>
#       <td>0.574</td>
#       <td>0.0010</td>
#       <td>96.1</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.593</td>
#       <td>0.0010</td>
#       <td>0.229</td>
#       <td>0.0010</td>
#       <td>38.7</td>
#       <td>0.374</td>
#       <td>0.0010</td>
#       <td>63.1</td>
#       <td>0.565</td>
#       <td>0.0010</td>
#       <td>95.4</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.584</td>
#       <td>0.0010</td>
#       <td>0.169</td>
#       <td>0.0010</td>
#       <td>28.9</td>
#       <td>0.276</td>
#       <td>0.0010</td>
#       <td>47.3</td>
#       <td>0.445</td>
#       <td>0.0010</td>
#       <td>76.3</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# Generating Plots (calling methods from KSG_MI_First.py)
# ================================================================================
# Plot generation finished. Plots should appear above.
#
# ================================================================================
# Comprehensive Text Results
# ================================================================================
#
# --- Results for k=3  ---
# Raw MI: 0.5786 bits (p=0.0010)
# CMI (All Controls): 0.3346 bits (p=0.0010), Retention: 57.8%
# CMI (Threshold Only): 0.4646 bits (p=0.0010), Retention: 80.3%
# CMI (NDT Only): 0.5932 bits (p=0.0010), Retention: 102.5%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.4429 bits (p=0.0010), Retention=76.6%
#   a_mean_s2: CMI=0.2249 bits (p=0.0010), Retention=38.9%
#   ndt_mean_s1: CMI=0.5122 bits (p=0.0010), Retention=88.6%
#   ndt_mean_s2: CMI=0.5067 bits (p=0.0010), Retention=87.7%
#
# --- Results for k=5  ---
# Raw MI: 0.5908 bits (p=0.0010)
# CMI (All Controls): 0.2944 bits (p=0.0010), Retention: 49.8%
# CMI (Threshold Only): 0.4411 bits (p=0.0010), Retention: 74.7%
# CMI (NDT Only): 0.5852 bits (p=0.0010), Retention: 99.0%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.3738 bits (p=0.0010), Retention=63.2%
#   a_mean_s2: CMI=0.2860 bits (p=0.0010), Retention=48.4%
#   ndt_mean_s1: CMI=0.4344 bits (p=0.0010), Retention=73.5%
#   ndt_mean_s2: CMI=0.5113 bits (p=0.0010), Retention=86.5%
#
# --- Results for k=7  ---
# Raw MI: 0.5979 bits (p=0.0010)
# CMI (All Controls): 0.2656 bits (p=0.0010), Retention: 44.4%
# CMI (Threshold Only): 0.4286 bits (p=0.0010), Retention: 71.7%
# CMI (NDT Only): 0.5744 bits (p=0.0010), Retention: 96.1%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.3454 bits (p=0.0010), Retention=58.0%
#   a_mean_s2: CMI=0.2913 bits (p=0.0010), Retention=48.9%
#   ndt_mean_s1: CMI=0.4030 bits (p=0.0010), Retention=67.7%
#   ndt_mean_s2: CMI=0.5083 bits (p=0.0010), Retention=85.4%
#
# --- Results for k=10  ---
# Raw MI: 0.5925 bits (p=0.0010)
# CMI (All Controls): 0.2291 bits (p=0.0010), Retention: 38.7%
# CMI (Threshold Only): 0.3739 bits (p=0.0010), Retention: 63.1%
# CMI (NDT Only): 0.5650 bits (p=0.0010), Retention: 95.4%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.3412 bits (p=0.0010), Retention=57.6%
#   a_mean_s2: CMI=0.3379 bits (p=0.0010), Retention=57.0%
#   ndt_mean_s1: CMI=0.4029 bits (p=0.0010), Retention=68.0%
#   ndt_mean_s2: CMI=0.4990 bits (p=0.0010), Retention=84.2%
#
# --- Results for k=28 (Data-driven) ---
# Raw MI: 0.5840 bits (p=0.0010)
# CMI (All Controls): 0.1690 bits (p=0.0010), Retention: 28.9%
# CMI (Threshold Only): 0.2763 bits (p=0.0010), Retention: 47.3%
# CMI (NDT Only): 0.4454 bits (p=0.0010), Retention: 76.3%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.2661 bits (p=0.0010), Retention=45.5%
#   a_mean_s2: CMI=0.2651 bits (p=0.0010), Retention=45.4%
#   ndt_mean_s1: CMI=0.3896 bits (p=0.0010), Retention=66.7%
#   ndt_mean_s2: CMI=0.5002 bits (p=0.0010), Retention=85.6%

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from IPython.display import display, HTML

# --- Import from your script ---
# Make sure KSG_MI_First.py is in the same directory or accessible
try:
    # We might need to reload the module if it was changed since the kernel started
    import importlib
    import KSG_MI_First
    importlib.reload(KSG_MI_First) # Reload to get the changes with plt.show()
    from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge
except ImportError:
    print("Error: Could not import from KSG_MI_First.py.")
    print("Make sure the file is in the same directory as the notebook or in the Python path.")
    # You might need to add the directory to the path if it's elsewhere:
    # import sys
    # sys.path.append('/path/to/your/script/directory')
    # from KSG_MI_First import KSGMutualInformationAnalyzer, load_and_merge

# --- Configuration ---
# <<< IMPORTANT: UPDATE THESE PATHS >>>
session1_path = 'Model2 ELP/Transformed_recoverd_param_ELP_S1_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'
session2_path = 'Model2 ELP/Transformed_recoverd_param_ELP_S2_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'

dataset_name_override = "ELP Model 2" # Optional: Or set to None to use automatic naming

# Analysis parameters
feature = 'alpha_s1'
target = 'alpha_s2'
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
n_permutations = 1000 # Lower for faster notebook execution, increase for final results (e.g., 5000)

# --- Load and Prepare Data ---
try:
    df_merged = load_and_merge(session1_path, session2_path)
    print(f"Data loaded successfully. Number of participants: {len(df_merged)}")

    # --- Initialize Analyzer ---
    analyzer = KSGMutualInformationAnalyzer(df_merged)

    # Determine dataset name
    dataset_name = dataset_name_override
    if dataset_name is None:
        dataset_name = analyzer.get_dataset_name(session1_path)
    print(f"Analyzing dataset: {dataset_name}")

    # --- Run Analysis ---
    results = {}
    individual_results = {}

    # Calculate data-driven k value
    k_data_driven = int(np.sqrt(len(df_merged)))
    print(f"\nData-driven k value (sqrt(N)): {k_data_driven}")

    # Define k values to test (including data-driven k)
    k_values = [5, 10, 20, 25, k_data_driven, 30]
    k_values = sorted(list(set(k_values))) # Remove duplicates and sort
    print(f"Testing k values: {k_values}")

    # Run analysis for each k
    for k in k_values:
        print(f"\nAnalyzing with k={k}...")
        # Reliability analysis (Raw MI, CMI All/Thresh/NDT)
        results[k] = analyzer.analyze_alpha_reliability(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )

        # Individual parameter analysis (CMI for each control var)
        individual_results[k] = analyzer.analyze_individual_parameters(
            feature=feature,
            target=target,
            control_vars=control_vars,
            k=k,
            n_permutations=n_permutations
        )
    print("\nAnalysis complete.")

    # --- Display Summary Table ---
    print("\n" + "="*80)
    print("Summary Table")
    print("="*80)
    summary_data = []
    for k in k_values:
        res_k = results[k]
        row = {
            'k': k,
            'Raw MI (bits)': f"{res_k['ksg_mi'][0]:.3f}",
            'p (Raw MI)': f"{res_k['ksg_mi'][1]:.4f}",
            'CMI All (bits)': f"{res_k.get('cond_mi_all', np.nan):.3f}",
            'p (All)': f"{res_k.get('p_value_all', np.nan):.4f}",
            'Ret All (%)': f"{res_k.get('retention_all', np.nan):.1f}",
            'CMI Thresh (bits)': f"{res_k.get('cond_mi_thresh', np.nan):.3f}",
            'p (Thresh)': f"{res_k.get('p_value_thresh', np.nan):.4f}",
            'Ret Thresh (%)': f"{res_k.get('retention_thresh', np.nan):.1f}",
            'CMI NDT (bits)': f"{res_k.get('cond_mi_ndt', np.nan):.3f}",
            'p (NDT)': f"{res_k.get('p_value_ndt', np.nan):.4f}",
            'Ret NDT (%)': f"{res_k.get('retention_ndt', np.nan):.1f}",
        }
        summary_data.append(row)

    df_summary = pd.DataFrame(summary_data)

   
    # --- ADD THIS LINE TO SAVE CSV ---
    csv_save_path = f"summary_results_{dataset_name.replace(' ', '_')}.csv"
    df_summary.to_csv(csv_save_path, index=False)
    print(f"Summary table saved to: {csv_save_path}")

    display(HTML(df_summary.to_html(index=False, na_rep='NaN')))


    # --- Generate Plots Inline by Calling Class Methods ---
    print("\n" + "="*80)
    print("Generating Plots (calling methods from KSG_MI_First.py)")
    print("="*80)

    # Call the main results plotting method
    # Pass one result dict for single point info, and all results for line plots
    analyzer.plot_results(
        results=results[k_values[-1]], # Pass results for one k (e.g., last one)
        all_k_results=results,
        feature=feature,
        target=target,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    # Call the individual parameter plotting method
    analyzer.plot_individual_parameter_effects(
        all_k_results=individual_results, # Pass the individual results dict
        feature=feature,
        target=target,
        control_vars=control_vars,
        session1_path=session1_path, # For naming
        dataset_name=dataset_name
    )

    print("\nPlot generation finished. Plots should appear above.")


    # --- Print Comprehensive Text Results ---
    print("\n" + "="*80)
    print("Comprehensive Text Results")
    print("="*80)
    for k in k_values:
        print(f"\n--- Results for k={k} {'(Data-driven)' if k == k_data_driven else ''} ---")
        res_k = results[k]
        res_indiv_k = individual_results[k]

        # Raw MI
        print(f"Raw MI: {res_k['ksg_mi'][0]:.4f} bits (p={res_k['ksg_mi'][1]:.4f})")

        # Grouped CMI
        if 'cond_mi_all' in res_k:
            print(f"CMI (All Controls): {res_k['cond_mi_all']:.4f} bits (p={res_k['p_value_all']:.4f}), Retention: {res_k['retention_all']:.1f}%")
        if 'cond_mi_thresh' in res_k:
            print(f"CMI (Threshold Only): {res_k['cond_mi_thresh']:.4f} bits (p={res_k['p_value_thresh']:.4f}), Retention: {res_k['retention_thresh']:.1f}%")
        if 'cond_mi_ndt' in res_k:
            print(f"CMI (NDT Only): {res_k['cond_mi_ndt']:.4f} bits (p={res_k['p_value_ndt']:.4f}), Retention: {res_k['retention_ndt']:.1f}%")

        # Individual CMI
        print("\nIndividual Parameter Effects:")
        for var in control_vars:
            if var in res_indiv_k:
                indiv_res = res_indiv_k[var]
                print(f"  {var}: CMI={indiv_res['cmi']:.4f} bits (p={indiv_res['p_value']:.4f}), Retention={indiv_res['retention']:.1f}%")
            else:
                print(f"  {var}: Not calculated")


except FileNotFoundError:
    print(f"Error: One or both input files not found.")
    print(f"Checked paths: '{session1_path}', '{session2_path}'")
    print("Please ensure the file paths at the top of the cell are correct.")
except ImportError:
     # Error message already printed in the import block
     pass
except Exception as e:
    print(f"An unexpected error occurred: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Available columns in session 1: ['Unnamed: 0', 'participant', 'v1', 'v2', 'a_mean_s1', 'ndt_mean_s1', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'participant', 'v1', 'v2', 'a_mean_s2', 'ndt_mean_s2', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Using identifier column: participant
# Shape before dropping NaNs in essential columns: (806, 43)
# Shape after dropping NaNs in essential columns: (806, 43)
# Data loaded successfully. Number of participants: 806
# Analyzing dataset: ELP Model 2
#
# Data-driven k value (sqrt(N)): 28
# Testing k values: [5, 10, 20, 25, 28, 30]
#
# Analyzing with k=5...
#
# Analyzing with k=10...
#
# Analyzing with k=20...
#
# Analyzing with k=25...
#
# Analyzing with k=28...
#
# Analyzing with k=30...
#
# Analysis complete.
#
# ================================================================================
# Summary Table
# ================================================================================
# Summary table saved to: summary_results_ELP_Model_2.csv
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>k</th>
#       <th>Raw MI (bits)</th>
#       <th>p (Raw MI)</th>
#       <th>CMI All (bits)</th>
#       <th>p (All)</th>
#       <th>Ret All (%)</th>
#       <th>CMI Thresh (bits)</th>
#       <th>p (Thresh)</th>
#       <th>Ret Thresh (%)</th>
#       <th>CMI NDT (bits)</th>
#       <th>p (NDT)</th>
#       <th>Ret NDT (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.902</td>
#       <td>0.0010</td>
#       <td>0.374</td>
#       <td>0.0010</td>
#       <td>41.4</td>
#       <td>0.557</td>
#       <td>0.0010</td>
#       <td>61.8</td>
#       <td>0.951</td>
#       <td>0.0010</td>
#       <td>105.4</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.930</td>
#       <td>0.0010</td>
#       <td>0.336</td>
#       <td>0.0010</td>
#       <td>36.1</td>
#       <td>0.580</td>
#       <td>0.0010</td>
#       <td>62.4</td>
#       <td>0.885</td>
#       <td>0.0010</td>
#       <td>95.1</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.965</td>
#       <td>0.0010</td>
#       <td>0.296</td>
#       <td>0.0010</td>
#       <td>30.6</td>
#       <td>0.533</td>
#       <td>0.0010</td>
#       <td>55.3</td>
#       <td>0.801</td>
#       <td>0.0010</td>
#       <td>83.1</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.959</td>
#       <td>0.0010</td>
#       <td>0.266</td>
#       <td>0.0010</td>
#       <td>27.7</td>
#       <td>0.512</td>
#       <td>0.0010</td>
#       <td>53.4</td>
#       <td>0.772</td>
#       <td>0.0010</td>
#       <td>80.5</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.949</td>
#       <td>0.0010</td>
#       <td>0.254</td>
#       <td>0.0010</td>
#       <td>26.7</td>
#       <td>0.502</td>
#       <td>0.0010</td>
#       <td>52.9</td>
#       <td>0.759</td>
#       <td>0.0010</td>
#       <td>80.0</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.952</td>
#       <td>0.0010</td>
#       <td>0.250</td>
#       <td>0.0010</td>
#       <td>26.3</td>
#       <td>0.499</td>
#       <td>0.0010</td>
#       <td>52.4</td>
#       <td>0.754</td>
#       <td>0.0010</td>
#       <td>79.2</td>
#     </tr>
#   </tbody>
# </table>
# ================================================================================
# Generating Plots (calling methods from KSG_MI_First.py)
# ================================================================================
# Plot generation finished. Plots should appear above.
#
# ================================================================================
# Comprehensive Text Results
# ================================================================================
#
# --- Results for k=5  ---
# Raw MI: 0.9020 bits (p=0.0010)
# CMI (All Controls): 0.3736 bits (p=0.0010), Retention: 41.4%
# CMI (Threshold Only): 0.5574 bits (p=0.0010), Retention: 61.8%
# CMI (NDT Only): 0.9508 bits (p=0.0010), Retention: 105.4%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.6083 bits (p=0.0010), Retention=67.4%
#   a_mean_s2: CMI=0.6283 bits (p=0.0010), Retention=69.6%
#   ndt_mean_s1: CMI=0.7459 bits (p=0.0010), Retention=82.7%
#   ndt_mean_s2: CMI=0.7974 bits (p=0.0010), Retention=88.4%
#
# --- Results for k=10  ---
# Raw MI: 0.9300 bits (p=0.0010)
# CMI (All Controls): 0.3355 bits (p=0.0010), Retention: 36.1%
# CMI (Threshold Only): 0.5800 bits (p=0.0010), Retention: 62.4%
# CMI (NDT Only): 0.8847 bits (p=0.0010), Retention: 95.1%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.5897 bits (p=0.0010), Retention=63.4%
#   a_mean_s2: CMI=0.6174 bits (p=0.0010), Retention=66.4%
#   ndt_mean_s1: CMI=0.7155 bits (p=0.0010), Retention=77.0%
#   ndt_mean_s2: CMI=0.8024 bits (p=0.0010), Retention=86.3%
#
# --- Results for k=20  ---
# Raw MI: 0.9645 bits (p=0.0010)
# CMI (All Controls): 0.2956 bits (p=0.0010), Retention: 30.6%
# CMI (Threshold Only): 0.5330 bits (p=0.0010), Retention: 55.3%
# CMI (NDT Only): 0.8013 bits (p=0.0010), Retention: 83.1%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.5754 bits (p=0.0010), Retention=59.7%
#   a_mean_s2: CMI=0.6315 bits (p=0.0010), Retention=65.5%
#   ndt_mean_s1: CMI=0.6940 bits (p=0.0010), Retention=72.0%
#   ndt_mean_s2: CMI=0.8021 bits (p=0.0010), Retention=83.2%
#
# --- Results for k=25  ---
# Raw MI: 0.9587 bits (p=0.0010)
# CMI (All Controls): 0.2660 bits (p=0.0010), Retention: 27.7%
# CMI (Threshold Only): 0.5119 bits (p=0.0010), Retention: 53.4%
# CMI (NDT Only): 0.7719 bits (p=0.0010), Retention: 80.5%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.5637 bits (p=0.0010), Retention=58.8%
#   a_mean_s2: CMI=0.6101 bits (p=0.0010), Retention=63.6%
#   ndt_mean_s1: CMI=0.6790 bits (p=0.0010), Retention=70.8%
#   ndt_mean_s2: CMI=0.8045 bits (p=0.0010), Retention=83.9%
#
# --- Results for k=28 (Data-driven) ---
# Raw MI: 0.9494 bits (p=0.0010)
# CMI (All Controls): 0.2535 bits (p=0.0010), Retention: 26.7%
# CMI (Threshold Only): 0.5020 bits (p=0.0010), Retention: 52.9%
# CMI (NDT Only): 0.7592 bits (p=0.0010), Retention: 80.0%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.5591 bits (p=0.0010), Retention=58.9%
#   a_mean_s2: CMI=0.6128 bits (p=0.0010), Retention=64.5%
#   ndt_mean_s1: CMI=0.6530 bits (p=0.0010), Retention=68.8%
#   ndt_mean_s2: CMI=0.8021 bits (p=0.0010), Retention=84.5%
#
# --- Results for k=30  ---
# Raw MI: 0.9517 bits (p=0.0010)
# CMI (All Controls): 0.2502 bits (p=0.0010), Retention: 26.3%
# CMI (Threshold Only): 0.4989 bits (p=0.0010), Retention: 52.4%
# CMI (NDT Only): 0.7537 bits (p=0.0010), Retention: 79.2%
#
# Individual Parameter Effects:
#   a_mean_s1: CMI=0.5589 bits (p=0.0010), Retention=58.7%
#   a_mean_s2: CMI=0.6061 bits (p=0.0010), Retention=63.7%
#   ndt_mean_s1: CMI=0.6549 bits (p=0.0010), Retention=68.8%
#   ndt_mean_s2: CMI=0.7910 bits (p=0.0010), Retention=83.1%

# %%
print("\nChecking ALL columns for NaNs before dropna:")
all_nan_counts = df_merged_before_dropna.isnull().sum()
print(all_nan_counts[all_nan_counts > 0]) # Show columns with any NaNs
# Out:
# Checking ALL columns for NaNs before dropna:
# mean_Crror_x     2
# q1_E_x           8
# q2_E_x           8
# q3_E_x           8
# q4_E_x           8
# mean_Crror_y     5
# q1_E_y          26
# q2_E_y          26
# q3_E_y          26
# q4_E_y          26
# dtype: int64

# %%
essential_cols = ['alpha_s1', 'alpha_s2', 'a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2'] # Add participant ID if needed elsewhere
df_merged.dropna(subset=essential_cols, inplace=True)

# %%
df_merged
# Out:
#                     Experiment_x  v1_mean_x  v2_mean_x  a_mean_s1  \
# 0     001_class_words_part_1.dat   1.735638  -1.647395   1.196706
# 1     002_class_words_part_1.dat   1.646541  -2.039125   1.171614
# 2     003_class_words_part_1.dat   2.671191  -2.926153   1.275182
# 3     004_class_words_part_1.dat   2.367079  -2.302624   1.111747
# 4     005_class_words_part_1.dat   2.961030  -3.611128   1.424967
# ..                           ...        ...        ...        ...
# 99   4009_class_words_part_1.dat   2.250238  -1.725310   2.374114
# 100  4010_class_words_part_1.dat   3.328432  -3.054612   1.917051
# 101  4011_class_words_part_1.dat   1.661596  -1.827556   0.984396
# 102  4012_class_words_part_1.dat   2.128155  -2.268161   1.129517
# 103  4013_class_words_part_1.dat   1.669823  -2.217093   1.203123
#
#      ndt_mean_s1  alpha_mean_x  accuracy_percentage_x  mean_log_rt_x  \
# 0       0.361422      1.458020               0.899749       6.522493
# 1       0.513238      1.927072               0.914573       6.651658
# 2       0.435791      1.956327               0.977500       6.492267
# 3       0.384127      1.457351               0.930000       6.427847
# 4       0.406036      1.885865               0.985000       6.439964
# ..           ...           ...                    ...            ...
# 99      0.319318      1.908496               0.984000       6.772617
# 100     0.273740      1.428962               0.930000       6.374000
# 101     0.339921      1.428092               0.864322       6.406905
# 102     0.374110      1.609163               0.942356       6.426793
# 103     0.389954      1.770988               0.897500       6.491461
#
#      RT_mean_correct_error_x  mean_correct_x  ...  \
# 0                   0.701662        0.703426  ...
# 1                   0.809281        0.795657  ...
# 2                   0.680427        0.675969  ...
# 3                   0.631073        0.631511  ...
# 4                   0.642445        0.639586  ...
# ..                       ...             ...  ...
# 99                  0.947483        0.940772  ...
# 100                 0.599220        0.598849  ...
# 101                 0.621442        0.624558  ...
# 102                 0.640702        0.639947  ...
# 103                 0.691530        0.680025  ...
#
#                                                 q2_E_y  \
# 0    [0.529 0.514 0.545 0.537 0.521 0.554 0.545 0.5...
# 1                      [0.825 0.85  0.841 0.737 0.833]
# 2                                        [0.674 0.579]
# 3    [0.513 0.522 0.546 0.553 0.538 0.545 0.529 0.5...
# 4                                              [0.483]
# ..                                                 ...
# 99                                 [1.058 0.809 1.058]
# 100  [0.536 0.521 0.528 0.498 0.53  0.513 0.537 0.5...
# 101  [0.538 0.562 0.586 0.53  0.555 0.53  0.586 0.5...
# 102                    [0.544 0.585 0.561 0.585 0.585]
# 103  [0.538 0.547 0.61  0.569 0.554 0.523 0.547 0.5...
#
#                                                 q3_E_y  \
# 0    [0.569 0.569 0.57  0.649 0.657 0.689 0.617 0.6...
# 1                      [0.897 0.881 0.881 0.898 0.882]
# 2                                              [0.874]
# 3    [0.577 0.641 0.585 0.578 0.642 0.602 0.626 0.6...
# 4                                               [0.53]
# ..                                                 ...
# 99                                             [1.354]
# 100        [0.6   0.593 0.545 0.545 0.538 0.538 0.585]
# 101  [0.611 0.619 0.594 0.642 0.658 0.642 0.609 0.6...
# 102              [0.625 0.618 0.617 0.593 0.593 0.713]
# 103  [0.658 0.689 0.707 0.73  0.633 0.627 0.649 0.6...
#
#                                                 q4_E_y alpha_mean_shifted_y  \
# 0    [0.785 1.041 1.713 0.93  0.705 0.762 0.921 0.7...             0.513741
# 1                [1.203 1.289 1.313 0.978 1.049 0.945]             0.645256
# 2                                        [0.921 0.929]             0.931810
# 3    [0.68  0.712 0.825 0.673 1.65  1.122 0.658 0.7...             0.420113
# 4                                               [0.69]             0.826650
# ..                                                 ...                  ...
# 99                                       [2.283 2.482]             0.975497
# 100  [0.601 0.689 0.681 0.946 0.69  0.611 0.842 0.634]             0.602745
# 101  [0.682 0.714 1.058 0.682 1.177 0.667 0.873 0.8...             0.474599
# 102              [0.985 0.825 0.721 0.818 0.818 0.745]             0.568852
# 103  [0.802 1.537 1.29  1.025 0.857 0.793 1.082 0.7...             0.713362
#
#     alpha_mean_arcsin_y alpha_boxcox_after_arcsin_s2  \
# 0              0.799141                    -0.184791
# 1              0.932779                    -0.065440
# 2              1.306602                     0.342727
# 3              0.705168                    -0.259941
# 4              1.141365                     0.149127
# ..                  ...                          ...
# 99             1.413616                     0.478935
# 100            0.888880                    -0.106237
# 101            0.759986                    -0.216998
# 102            0.854469                    -0.137133
# 103            1.005832                     0.005845
#
#     accuracy_percentage_arcsin_y accuracy_percentage_boxcox_after_arcsin_y  \
# 0                       1.187299                                  0.273387
# 1                       1.333769                                  0.650661
# 2                       1.438120                                  1.043981
# 3                       1.232291                                  0.370875
# 4                       1.458759                                  1.136751
# ..                           ...                                       ...
# 99                      1.415041                                  0.946445
# 100                     1.279465                                  0.489832
# 101                     1.197742                                  0.294718
# 102                     1.323329                                  0.617612
# 103                     1.252824                                  0.420433
#
#      alpha_s1  alpha_s2
# 0   -0.225418 -0.184791
# 1    0.338815 -0.065440
# 2    0.421069  0.342727
# 3   -0.225926 -0.259941
# 4    0.250195  0.149127
# ..        ...       ...
# 99   0.296063  0.478935
# 100 -0.247123 -0.106237
# 101 -0.247762 -0.216998
# 102 -0.099388 -0.137133
# 103  0.074218  0.005845
#
# [101 rows x 55 columns]
