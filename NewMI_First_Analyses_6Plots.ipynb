# %%
import NewMI_First
import numpy as np
import matplotlib.pyplot as plt

# Load your data
session1_path = 'Model2 LDT RMT/EZ_recognition_memory_part1_transformed.csv'
session2_path = 'Model2 LDT RMT/EZ_recognition_memory_part2_transformed.csv'
df_merged = NewMI_First.load_and_merge(session1_path, session2_path)

# Initialize analyzer
analyzer = NewMI_First.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Define a range of bandwidths to test
# Using a logarithmic scale to better explore the parameter space
base_bandwidth = np.std(analyzer.data['alpha_s1'].values) * (4/(3*len(analyzer.data)))**(1/5)
bandwidths = [
    base_bandwidth * 1.0,  # Original Silverman's rule
    base_bandwidth * 1.5,  # 1.5x Silverman
    base_bandwidth * 2.0,  # 2x Silverman
    base_bandwidth * 2.5,  # 2.5x Silverman
    base_bandwidth * 3.0   # 3x Silverman
]

print(f"Base bandwidth (Silverman's rule): {base_bandwidth:.4f}")
print(f"Testing bandwidths: {[f'{bw:.4f}' for bw in bandwidths]}")

# Set verbose output to False to reduce output clutter
import warnings
warnings.filterwarnings('ignore')

# Run the bandwidth sensitivity analysis for conditional MI
bandwidth_results = analyzer.conditional_mi_bandwidth_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,  # Shrinkage parameter
    dataset_name="RMT Model 2"
)

# The method automatically produces plots, but we can also print some key results
print("\nSummary of Results:")
for i, bw in enumerate(bandwidth_results['bandwidths']):
    print(f"\nBandwidth: {bw:.4f}")
    print(f"Raw MI: {bandwidth_results['raw_mi'][i]:.4f} bits")
    
    if 'retention_threshold' in bandwidth_results:
        print(f"Threshold-only retention: {bandwidth_results['retention_threshold'][i]:.1f}% (p={bandwidth_results['p_values_threshold'][i]:.4f})")
    
    if 'retention_ndt' in bandwidth_results:
        print(f"NDT-only retention: {bandwidth_results['retention_ndt'][i]:.1f}% (p={bandwidth_results['p_values_ndt'][i]:.4f})")
    
    if 'retention_all' in bandwidth_results:
        print(f"All parameters retention: {bandwidth_results['retention_all'][i]:.1f}% (p={bandwidth_results['p_values_all'][i]:.4f})")
        

# Run the individual parameter analysis
individual_results = analyzer.individual_parameter_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,
    dataset_name="RMT Model 2"
)
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Available columns in session 1: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s1', 'ndt_mean_s1', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s2', 'ndt_mean_s2', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: participant_ID
# Base bandwidth (Silverman's rule): 0.0958
# Testing bandwidths: ['0.0958', '0.1438', '0.1917', '0.2396', '0.2875']
#
# Analyzing bandwidth: 0.0958
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of control matrix: (75, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# a_mean_s1 - ndt_mean_s1: r = -0.1149
# a_mean_s1 - ndt_mean_s2: r = 0.0353
# a_mean_s2 - ndt_mean_s1: r = 0.0763
# a_mean_s2 - ndt_mean_s2: r = -0.3325
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.0958
#
# Summary statistics of log probabilities:
# log_px: mean = 0.1189, std = 0.5608
# log_py: mean = 0.0543, std = 0.5014
# log_pz: mean = 2.8549, std = 0.6995
# log_pxz: mean = 3.5876, std = 0.5219
# log_pyz: mean = 3.5871, std = 0.5084
# log_pxyz: mean = 4.5951, std = 0.3433
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 7.4500
# Mean(log_pxz + log_pyz): 7.1747
# Final CMI: 0.2754
#
# Components contributing to CMI:
# Mean(log_pxyz): 4.5951
# Mean(log_pz): 2.8549
# Mean(log_pxz): 3.5876
# Mean(log_pyz): 3.5871
# CMI = 4.5951 + 2.8549 - 3.5876 - 3.5871 = 0.2754
# Permutation test p-value: 0.0064
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 75
# Dimensionality of threshold matrix: (75, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# Using bandwidth: 0.0958
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.1435
# Mean(log_pxz + log_pyz): 1.8523
# Final Threshold CMI: 0.2912
# Permutation test p-value: 0.0142
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of NDT matrix: (75, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.0958
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 5.2140
# Mean(log_pxz + log_pyz): 5.0058
# Final NDT CMI: 0.2082
# Permutation test p-value: 0.0004
#
# Analyzing bandwidth: 0.1438
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of control matrix: (75, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# a_mean_s1 - ndt_mean_s1: r = -0.1149
# a_mean_s1 - ndt_mean_s2: r = 0.0353
# a_mean_s2 - ndt_mean_s1: r = 0.0763
# a_mean_s2 - ndt_mean_s2: r = -0.3325
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.1438
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0908, std = 0.4726
# log_py: mean = 0.0196, std = 0.4380
# log_pz: mean = 1.9699, std = 0.7621
# log_pxz: mean = 2.3289, std = 0.7226
# log_pyz: mean = 2.3123, std = 0.6846
# log_pxyz: mean = 2.8158, std = 0.6139
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 4.7857
# Mean(log_pxz + log_pyz): 4.6411
# Final CMI: 0.1446
#
# Components contributing to CMI:
# Mean(log_pxyz): 2.8158
# Mean(log_pz): 1.9699
# Mean(log_pxz): 2.3289
# Mean(log_pyz): 2.3123
# CMI = 2.8158 + 1.9699 - 2.3289 - 2.3123 = 0.1446
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 75
# Dimensionality of threshold matrix: (75, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# Using bandwidth: 0.1438
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.9951
# Mean(log_pxz + log_pyz): 0.8543
# Final Threshold CMI: 0.1408
# Permutation test p-value: 0.0006
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of NDT matrix: (75, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.1438
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.8259
# Mean(log_pxz + log_pyz): 3.7157
# Final NDT CMI: 0.1102
# Permutation test p-value: 0.0002
#
# Analyzing bandwidth: 0.1917
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of control matrix: (75, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# a_mean_s1 - ndt_mean_s1: r = -0.1149
# a_mean_s1 - ndt_mean_s2: r = 0.0353
# a_mean_s2 - ndt_mean_s1: r = 0.0763
# a_mean_s2 - ndt_mean_s2: r = -0.3325
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.1917
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0488, std = 0.3828
# log_py: mean = -0.0199, std = 0.3681
# log_pz: mean = 1.3042, std = 0.7346
# log_pxz: mean = 1.4952, std = 0.7529
# log_pyz: mean = 1.4613, std = 0.7122
# log_pxyz: mean = 1.7251, std = 0.6999
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.0294
# Mean(log_pxz + log_pyz): 2.9565
# Final CMI: 0.0728
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.7251
# Mean(log_pz): 1.3042
# Mean(log_pxz): 1.4952
# Mean(log_pyz): 1.4613
# CMI = 1.7251 + 1.3042 - 1.4952 - 1.4613 = 0.0728
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 75
# Dimensionality of threshold matrix: (75, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# Using bandwidth: 0.1917
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.3077
# Mean(log_pxz + log_pyz): 0.2376
# Final Threshold CMI: 0.0702
# Permutation test p-value: 0.0004
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of NDT matrix: (75, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.1917
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.7286
# Mean(log_pxz + log_pyz): 2.6644
# Final NDT CMI: 0.0641
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.2396
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of control matrix: (75, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# a_mean_s1 - ndt_mean_s1: r = -0.1149
# a_mean_s1 - ndt_mean_s2: r = 0.0353
# a_mean_s2 - ndt_mean_s1: r = 0.0763
# a_mean_s2 - ndt_mean_s2: r = -0.3325
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.2396
#
# Summary statistics of log probabilities:
# log_px: mean = -0.0073, std = 0.3063
# log_py: mean = -0.0687, std = 0.3026
# log_pz: mean = 0.7485, std = 0.6846
# log_pxz: mean = 0.8270, std = 0.7161
# log_pyz: mean = 0.7876, std = 0.6785
# log_pxyz: mean = 0.9072, std = 0.6865
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.6557
# Mean(log_pxz + log_pyz): 1.6146
# Final CMI: 0.0411
#
# Components contributing to CMI:
# Mean(log_pxyz): 0.9072
# Mean(log_pz): 0.7485
# Mean(log_pxz): 0.8270
# Mean(log_pyz): 0.7876
# CMI = 0.9072 + 0.7485 - 0.8270 - 0.7876 = 0.0411
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 75
# Dimensionality of threshold matrix: (75, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# Using bandwidth: 0.2396
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.2309
# Mean(log_pxz + log_pyz): -0.2705
# Final Threshold CMI: 0.0397
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of NDT matrix: (75, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.2396
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.8029
# Mean(log_pxz + log_pyz): 1.7625
# Final NDT CMI: 0.0404
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.2875
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of control matrix: (75, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# a_mean_s1 - ndt_mean_s1: r = -0.1149
# a_mean_s1 - ndt_mean_s2: r = 0.0353
# a_mean_s2 - ndt_mean_s1: r = 0.0763
# a_mean_s2 - ndt_mean_s2: r = -0.3325
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.2875
#
# Summary statistics of log probabilities:
# log_px: mean = -0.0730, std = 0.2459
# log_py: mean = -0.1259, std = 0.2479
# log_pz: mean = 0.2635, std = 0.6306
# log_pxz: mean = 0.2460, std = 0.6619
# log_pyz: mean = 0.2084, std = 0.6293
# log_pxyz: mean = 0.2165, std = 0.6442
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.4799
# Mean(log_pxz + log_pyz): 0.4544
# Final CMI: 0.0255
#
# Components contributing to CMI:
# Mean(log_pxyz): 0.2165
# Mean(log_pz): 0.2635
# Mean(log_pxz): 0.2460
# Mean(log_pyz): 0.2084
# CMI = 0.2165 + 0.2635 - 0.2460 - 0.2084 = 0.0255
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 75
# Dimensionality of threshold matrix: (75, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# Using bandwidth: 0.2875
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.7160
# Mean(log_pxz + log_pyz): -0.7409
# Final Threshold CMI: 0.0249
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of NDT matrix: (75, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.2875
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.9931
# Mean(log_pxz + log_pyz): 0.9664
# Final NDT CMI: 0.0267
# Permutation test p-value: 0.0002
# Summary of Results:
#
# Bandwidth: 0.0958
# Raw MI: 0.1245 bits
# Threshold-only retention: 233.9% (p=0.0142)
# NDT-only retention: 167.2% (p=0.0004)
# All parameters retention: 221.2% (p=0.0064)
#
# Bandwidth: 0.1438
# Raw MI: 0.0854 bits
# Threshold-only retention: 164.9% (p=0.0006)
# NDT-only retention: 129.0% (p=0.0002)
# All parameters retention: 169.3% (p=0.0000)
#
# Bandwidth: 0.1917
# Raw MI: 0.0676 bits
# Threshold-only retention: 103.8% (p=0.0004)
# NDT-only retention: 94.8% (p=0.0000)
# All parameters retention: 107.7% (p=0.0000)
#
# Bandwidth: 0.2396
# Raw MI: 0.0575 bits
# Threshold-only retention: 69.0% (p=0.0000)
# NDT-only retention: 70.3% (p=0.0000)
# All parameters retention: 71.4% (p=0.0000)
#
# Bandwidth: 0.2875
# Raw MI: 0.0512 bits
# Threshold-only retention: 48.6% (p=0.0000)
# NDT-only retention: 52.2% (p=0.0002)
# All parameters retention: 49.9% (p=0.0000)
#
# Analyzing bandwidth: 0.0958
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1438
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1917
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.2396
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.2875
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...

# %%
import NewMI_First

# Load your data
session1_path = 'Model1 LDT RMT/rmt_session_1_data_transformed.csv'  # replace with your actual path
session2_path = 'Model1 LDT RMT/rmt_session_2_data_transformed.csv'
df_merged = NewMI_First.load_and_merge(session1_path, session2_path)

analyzer = NewMI_First.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Define a range of bandwidths to test
# Using a logarithmic scale to better explore the parameter space
base_bandwidth = np.std(analyzer.data['alpha_s1'].values) * (4/(3*len(analyzer.data)))**(1/5)
bandwidths = [
    base_bandwidth * 1.0,  # Original Silverman's rule
    base_bandwidth * 1.5,  # 1.5x Silverman
    base_bandwidth * 2.0,  # 2x Silverman
    base_bandwidth * 2.5,  # 2.5x Silverman
    base_bandwidth * 3.0   # 3x Silverman
]

print(f"Base bandwidth (Silverman's rule): {base_bandwidth:.4f}")
print(f"Testing bandwidths: {[f'{bw:.4f}' for bw in bandwidths]}")

# Set verbose output to False to reduce output clutter
import warnings
warnings.filterwarnings('ignore')

# Run the bandwidth sensitivity analysis for conditional MI
bandwidth_results = analyzer.conditional_mi_bandwidth_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,  # Shrinkage parameter
    dataset_name="RMT Model 1"
)

# The method automatically produces plots, but we can also print some key results
print("\nSummary of Results:")
for i, bw in enumerate(bandwidth_results['bandwidths']):
    print(f"\nBandwidth: {bw:.4f}")
    print(f"Raw MI: {bandwidth_results['raw_mi'][i]:.4f} bits")
    
    if 'retention_threshold' in bandwidth_results:
        print(f"Threshold-only retention: {bandwidth_results['retention_threshold'][i]:.1f}% (p={bandwidth_results['p_values_threshold'][i]:.4f})")
    
    if 'retention_ndt' in bandwidth_results:
        print(f"NDT-only retention: {bandwidth_results['retention_ndt'][i]:.1f}% (p={bandwidth_results['p_values_ndt'][i]:.4f})")
    
    if 'retention_all' in bandwidth_results:
        print(f"All parameters retention: {bandwidth_results['retention_all'][i]:.1f}% (p={bandwidth_results['p_values_all'][i]:.4f})")
# Run the individual parameter analysis
individual_results = analyzer.individual_parameter_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,
    dataset_name="RMT Model 1"
)
# Out:
# Available columns in session 1: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s1', 'ndt_mean_s1', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s2', 'ndt_mean_s2', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: ID
# Base bandwidth (Silverman's rule): 0.0888
# Testing bandwidths: ['0.0888', '0.1332', '0.1776', '0.2220', '0.2664']
#
# Analyzing bandwidth: 0.0888
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of control matrix: (97, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# a_mean_s1 - ndt_mean_s1: r = -0.1951
# a_mean_s1 - ndt_mean_s2: r = -0.0428
# a_mean_s2 - ndt_mean_s1: r = -0.2710
# a_mean_s2 - ndt_mean_s2: r = -0.3109
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.0888
#
# Summary statistics of log probabilities:
# log_px: mean = 0.1501, std = 0.5309
# log_py: mean = 0.5823, std = 0.7231
# log_pz: mean = 2.9011, std = 0.6550
# log_pxz: mean = 3.6257, std = 0.4600
# log_pyz: mean = 3.9354, std = 0.5827
# log_pxyz: mean = 4.8545, std = 0.3298
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 7.7556
# Mean(log_pxz + log_pyz): 7.5611
# Final CMI: 0.1945
#
# Components contributing to CMI:
# Mean(log_pxyz): 4.8545
# Mean(log_pz): 2.9011
# Mean(log_pxz): 3.6257
# Mean(log_pyz): 3.9354
# CMI = 4.8545 + 2.9011 - 3.6257 - 3.9354 = 0.1945
# Permutation test p-value: 0.0654
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 97
# Dimensionality of threshold matrix: (97, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# Using bandwidth: 0.0888
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.1715
# Mean(log_pxz + log_pyz): 1.9561
# Final Threshold CMI: 0.2154
# Permutation test p-value: 0.0406
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of NDT matrix: (97, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.0888
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 6.0659
# Mean(log_pxz + log_pyz): 5.9158
# Final NDT CMI: 0.1501
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1332
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of control matrix: (97, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# a_mean_s1 - ndt_mean_s1: r = -0.1951
# a_mean_s1 - ndt_mean_s2: r = -0.0428
# a_mean_s2 - ndt_mean_s1: r = -0.2710
# a_mean_s2 - ndt_mean_s2: r = -0.3109
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.1332
#
# Summary statistics of log probabilities:
# log_px: mean = 0.1217, std = 0.4565
# log_py: mean = 0.4763, std = 0.6420
# log_pz: mean = 2.0151, std = 0.7422
# log_pxz: mean = 2.3845, std = 0.6605
# log_pyz: mean = 2.7059, std = 0.7751
# log_pxyz: mean = 3.1728, std = 0.6043
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 5.1879
# Mean(log_pxz + log_pyz): 5.0904
# Final CMI: 0.0975
#
# Components contributing to CMI:
# Mean(log_pxyz): 3.1728
# Mean(log_pz): 2.0151
# Mean(log_pxz): 2.3845
# Mean(log_pyz): 2.7059
# CMI = 3.1728 + 2.0151 - 2.3845 - 2.7059 = 0.0975
# Permutation test p-value: 0.0022
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 97
# Dimensionality of threshold matrix: (97, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# Using bandwidth: 0.1332
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.0932
# Mean(log_pxz + log_pyz): 0.9890
# Final Threshold CMI: 0.1042
# Permutation test p-value: 0.0032
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of NDT matrix: (97, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.1332
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 4.6362
# Mean(log_pxz + log_pyz): 4.5605
# Final NDT CMI: 0.0758
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1776
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of control matrix: (97, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# a_mean_s1 - ndt_mean_s1: r = -0.1951
# a_mean_s1 - ndt_mean_s2: r = -0.0428
# a_mean_s2 - ndt_mean_s1: r = -0.2710
# a_mean_s2 - ndt_mean_s2: r = -0.3109
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.1776
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0828, std = 0.3743
# log_py: mean = 0.3633, std = 0.5545
# log_pz: mean = 1.3620, std = 0.7409
# log_pxz: mean = 1.5728, std = 0.7205
# log_pyz: mean = 1.8436, std = 0.8178
# log_pxyz: mean = 2.1061, std = 0.7387
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.4681
# Mean(log_pxz + log_pyz): 3.4164
# Final CMI: 0.0517
#
# Components contributing to CMI:
# Mean(log_pxyz): 2.1061
# Mean(log_pz): 1.3620
# Mean(log_pxz): 1.5728
# Mean(log_pyz): 1.8436
# CMI = 2.1061 + 1.3620 - 1.5728 - 1.8436 = 0.0517
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 97
# Dimensionality of threshold matrix: (97, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# Using bandwidth: 0.1776
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.4292
# Mean(log_pxz + log_pyz): 0.3767
# Final Threshold CMI: 0.0525
# Permutation test p-value: 0.0050
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of NDT matrix: (97, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.1776
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.4629
# Mean(log_pxz + log_pyz): 3.4270
# Final NDT CMI: 0.0359
# Permutation test p-value: 0.0002
#
# Analyzing bandwidth: 0.2220
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of control matrix: (97, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# a_mean_s1 - ndt_mean_s1: r = -0.1951
# a_mean_s1 - ndt_mean_s2: r = -0.0428
# a_mean_s2 - ndt_mean_s1: r = -0.2710
# a_mean_s2 - ndt_mean_s2: r = -0.3109
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.2220
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0313, std = 0.3045
# log_py: mean = 0.2525, std = 0.4701
# log_pz: mean = 0.8255, std = 0.6977
# log_pxz: mean = 0.9302, std = 0.7071
# log_pyz: mean = 1.1483, std = 0.7870
# log_pxyz: mean = 1.2792, std = 0.7685
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.1047
# Mean(log_pxz + log_pyz): 2.0784
# Final CMI: 0.0263
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.2792
# Mean(log_pz): 0.8255
# Mean(log_pxz): 0.9302
# Mean(log_pyz): 1.1483
# CMI = 1.2792 + 0.8255 - 0.9302 - 1.1483 = 0.0263
# Permutation test p-value: 0.0038
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 97
# Dimensionality of threshold matrix: (97, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# Using bandwidth: 0.2220
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.0991
# Mean(log_pxz + log_pyz): -0.1247
# Final Threshold CMI: 0.0256
# Permutation test p-value: 0.0120
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of NDT matrix: (97, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.2220
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.4762
# Mean(log_pxz + log_pyz): 2.4574
# Final NDT CMI: 0.0189
# Permutation test p-value: 0.0048
#
# Analyzing bandwidth: 0.2664
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of control matrix: (97, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# a_mean_s1 - ndt_mean_s1: r = -0.1951
# a_mean_s1 - ndt_mean_s2: r = -0.0428
# a_mean_s2 - ndt_mean_s1: r = -0.2710
# a_mean_s2 - ndt_mean_s2: r = -0.3109
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.2664
#
# Summary statistics of log probabilities:
# log_px: mean = -0.0291, std = 0.2481
# log_py: mean = 0.1464, std = 0.3928
# log_pz: mean = 0.3631, std = 0.6324
# log_pxz: mean = 0.3793, std = 0.6526
# log_pyz: mean = 0.5520, std = 0.7263
# log_pxyz: mean = 0.5809, std = 0.7380
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.9440
# Mean(log_pxz + log_pyz): 0.9314
# Final CMI: 0.0126
#
# Components contributing to CMI:
# Mean(log_pxyz): 0.5809
# Mean(log_pz): 0.3631
# Mean(log_pxz): 0.3793
# Mean(log_pyz): 0.5520
# CMI = 0.5809 + 0.3631 - 0.3793 - 0.5520 = 0.0126
# Permutation test p-value: 0.0114
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 97
# Dimensionality of threshold matrix: (97, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# Using bandwidth: 0.2664
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.5665
# Mean(log_pxz + log_pyz): -0.5784
# Final Threshold CMI: 0.0119
# Permutation test p-value: 0.0410
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of NDT matrix: (97, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.2664
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.6212
# Mean(log_pxz + log_pyz): 1.6103
# Final NDT CMI: 0.0109
# Permutation test p-value: 0.0064
# Summary of Results:
#
# Bandwidth: 0.0888
# Raw MI: 0.0840 bits
# Threshold-only retention: 256.5% (p=0.0406)
# NDT-only retention: 178.7% (p=0.0000)
# All parameters retention: 231.6% (p=0.0654)
#
# Bandwidth: 0.1332
# Raw MI: 0.0452 bits
# Threshold-only retention: 230.6% (p=0.0032)
# NDT-only retention: 167.7% (p=0.0000)
# All parameters retention: 215.7% (p=0.0022)
#
# Bandwidth: 0.1776
# Raw MI: 0.0250 bits
# Threshold-only retention: 209.9% (p=0.0050)
# NDT-only retention: 143.4% (p=0.0002)
# All parameters retention: 206.7% (p=0.0000)
#
# Bandwidth: 0.2220
# Raw MI: 0.0167 bits
# Threshold-only retention: 153.3% (p=0.0120)
# NDT-only retention: 112.8% (p=0.0048)
# All parameters retention: 157.2% (p=0.0038)
#
# Bandwidth: 0.2664
# Raw MI: 0.0130 bits
# Threshold-only retention: 91.8% (p=0.0410)
# NDT-only retention: 84.0% (p=0.0064)
# All parameters retention: 97.3% (p=0.0114)
#
# Analyzing bandwidth: 0.0888
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1332
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1776
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.2220
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.2664
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...

# %%
import NewMI_First

# Load your data
session1_path = 'Model1 LDT RMT/ldt_session_1_data_transformed.csv'  # replace with your actual path
session2_path = 'Model1 LDT RMT/ldt_session_2_data_transformed.csv'
df_merged = NewMI_First.load_and_merge(session1_path, session2_path)

analyzer = NewMI_First.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Define a range of bandwidths to test
# Using a logarithmic scale to better explore the parameter space
base_bandwidth = np.std(analyzer.data['alpha_s1'].values) * (4/(3*len(analyzer.data)))**(1/5)
bandwidths = [
    base_bandwidth * 1.0,  # Original Silverman's rule
    base_bandwidth * 1.5,  # 1.5x Silverman
    base_bandwidth * 2.0,  # 2x Silverman
    base_bandwidth * 2.5,  # 2.5x Silverman
    base_bandwidth * 3.0   # 3x Silverman
]

print(f"Base bandwidth (Silverman's rule): {base_bandwidth:.4f}")
print(f"Testing bandwidths: {[f'{bw:.4f}' for bw in bandwidths]}")

# Set verbose output to False to reduce output clutter
import warnings
warnings.filterwarnings('ignore')

# Run the bandwidth sensitivity analysis for conditional MI
bandwidth_results = analyzer.conditional_mi_bandwidth_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,  # Shrinkage parameter
    dataset_name="LDT Model 1"
)

# The method automatically produces plots, but we can also print some key results
print("\nSummary of Results:")
for i, bw in enumerate(bandwidth_results['bandwidths']):
    print(f"\nBandwidth: {bw:.4f}")
    print(f"Raw MI: {bandwidth_results['raw_mi'][i]:.4f} bits")
    
    if 'retention_threshold' in bandwidth_results:
        print(f"Threshold-only retention: {bandwidth_results['retention_threshold'][i]:.1f}% (p={bandwidth_results['p_values_threshold'][i]:.4f})")
    
    if 'retention_ndt' in bandwidth_results:
        print(f"NDT-only retention: {bandwidth_results['retention_ndt'][i]:.1f}% (p={bandwidth_results['p_values_ndt'][i]:.4f})")
    
    if 'retention_all' in bandwidth_results:
        print(f"All parameters retention: {bandwidth_results['retention_all'][i]:.1f}% (p={bandwidth_results['p_values_all'][i]:.4f})")

# Run the individual parameter analysis
individual_results = analyzer.individual_parameter_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,
    dataset_name="LDT Model 1"
)
# Out:
# Available columns in session 1: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s1', 'ndt_mean_s1', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s2', 'ndt_mean_s2', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: ID
# Base bandwidth (Silverman's rule): 0.0895
# Testing bandwidths: ['0.0895', '0.1343', '0.1791', '0.2239', '0.2686']
#
# Analyzing bandwidth: 0.0895
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of control matrix: (104, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# a_mean_s1 - ndt_mean_s1: r = 0.0481
# a_mean_s1 - ndt_mean_s2: r = 0.1333
# a_mean_s2 - ndt_mean_s1: r = 0.0206
# a_mean_s2 - ndt_mean_s2: r = 0.1147
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.0895
#
# Summary statistics of log probabilities:
# log_px: mean = 0.1377, std = 0.4340
# log_py: mean = 0.2111, std = 0.4433
# log_pz: mean = 3.1761, std = 0.7364
# log_pxz: mean = 3.8976, std = 0.6066
# log_pyz: mean = 3.8599, std = 0.5542
# log_pxyz: mean = 4.8837, std = 0.3850
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 8.0598
# Mean(log_pxz + log_pyz): 7.7575
# Final CMI: 0.3023
#
# Components contributing to CMI:
# Mean(log_pxyz): 4.8837
# Mean(log_pz): 3.1761
# Mean(log_pxz): 3.8976
# Mean(log_pyz): 3.8599
# CMI = 4.8837 + 3.1761 - 3.8976 - 3.8599 = 0.3023
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 104
# Dimensionality of threshold matrix: (104, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# Using bandwidth: 0.0895
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.4611
# Mean(log_pxz + log_pyz): 2.1305
# Final Threshold CMI: 0.3306
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of NDT matrix: (104, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.0895
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 5.9517
# Mean(log_pxz + log_pyz): 5.7042
# Final NDT CMI: 0.2475
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1343
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of control matrix: (104, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# a_mean_s1 - ndt_mean_s1: r = 0.0481
# a_mean_s1 - ndt_mean_s2: r = 0.1333
# a_mean_s2 - ndt_mean_s1: r = 0.0206
# a_mean_s2 - ndt_mean_s2: r = 0.1147
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.1343
#
# Summary statistics of log probabilities:
# log_px: mean = 0.1039, std = 0.3826
# log_py: mean = 0.1687, std = 0.3843
# log_pz: mean = 2.2813, std = 0.7616
# log_pxz: mean = 2.6965, std = 0.7063
# log_pyz: mean = 2.6722, std = 0.7070
# log_pxyz: mean = 3.2574, std = 0.6284
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 5.5387
# Mean(log_pxz + log_pyz): 5.3686
# Final CMI: 0.1700
#
# Components contributing to CMI:
# Mean(log_pxyz): 3.2574
# Mean(log_pz): 2.2813
# Mean(log_pxz): 2.6965
# Mean(log_pyz): 2.6722
# CMI = 3.2574 + 2.2813 - 2.6965 - 2.6722 = 0.1700
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 104
# Dimensionality of threshold matrix: (104, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# Using bandwidth: 0.1343
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.4259
# Mean(log_pxz + log_pyz): 1.2504
# Final Threshold CMI: 0.1755
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of NDT matrix: (104, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.1343
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 4.4867
# Mean(log_pxz + log_pyz): 4.3142
# Final NDT CMI: 0.1725
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1791
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of control matrix: (104, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# a_mean_s1 - ndt_mean_s1: r = 0.0481
# a_mean_s1 - ndt_mean_s2: r = 0.1333
# a_mean_s2 - ndt_mean_s1: r = 0.0206
# a_mean_s2 - ndt_mean_s2: r = 0.1147
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.1791
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0627, std = 0.3253
# log_py: mean = 0.1197, std = 0.3199
# log_pz: mean = 1.5899, std = 0.7430
# log_pxz: mean = 1.8477, std = 0.7128
# log_pyz: mean = 1.8381, std = 0.7263
# log_pxyz: mean = 2.2002, std = 0.6906
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.7901
# Mean(log_pxz + log_pyz): 3.6858
# Final CMI: 0.1043
#
# Components contributing to CMI:
# Mean(log_pxyz): 2.2002
# Mean(log_pz): 1.5899
# Mean(log_pxz): 1.8477
# Mean(log_pyz): 1.8381
# CMI = 2.2002 + 1.5899 - 1.8477 - 1.8381 = 0.1043
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 104
# Dimensionality of threshold matrix: (104, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# Using bandwidth: 0.1791
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.7460
# Mean(log_pxz + log_pyz): 0.6387
# Final Threshold CMI: 0.1073
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of NDT matrix: (104, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.1791
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.3260
# Mean(log_pxz + log_pyz): 3.1991
# Final NDT CMI: 0.1269
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.2239
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of control matrix: (104, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# a_mean_s1 - ndt_mean_s1: r = 0.0481
# a_mean_s1 - ndt_mean_s2: r = 0.1333
# a_mean_s2 - ndt_mean_s1: r = 0.0206
# a_mean_s2 - ndt_mean_s2: r = 0.1147
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.2239
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0114, std = 0.2709
# log_py: mean = 0.0604, std = 0.2630
# log_pz: mean = 1.0121, std = 0.7097
# log_pxz: mean = 1.1548, std = 0.6927
# log_pyz: mean = 1.1553, std = 0.7037
# log_pxyz: mean = 1.3668, std = 0.6838
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.3789
# Mean(log_pxz + log_pyz): 2.3102
# Final CMI: 0.0687
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.3668
# Mean(log_pz): 1.0121
# Mean(log_pxz): 1.1548
# Mean(log_pyz): 1.1553
# CMI = 1.3668 + 1.0121 - 1.1548 - 1.1553 = 0.0687
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 104
# Dimensionality of threshold matrix: (104, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# Using bandwidth: 0.2239
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.1787
# Mean(log_pxz + log_pyz): 0.1082
# Final Threshold CMI: 0.0705
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of NDT matrix: (104, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.2239
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.3482
# Mean(log_pxz + log_pyz): 2.2585
# Final NDT CMI: 0.0896
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.2686
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of control matrix: (104, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# a_mean_s1 - ndt_mean_s1: r = 0.0481
# a_mean_s1 - ndt_mean_s2: r = 0.1333
# a_mean_s2 - ndt_mean_s1: r = 0.0206
# a_mean_s2 - ndt_mean_s2: r = 0.1147
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.2686
#
# Summary statistics of log probabilities:
# log_px: mean = -0.0480, std = 0.2241
# log_py: mean = -0.0062, std = 0.2152
# log_pz: mean = 0.5133, std = 0.6647
# log_pxz: mean = 0.5572, std = 0.6554
# log_pyz: mean = 0.5628, std = 0.6648
# log_pxyz: mean = 0.6530, std = 0.6545
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.1663
# Mean(log_pxz + log_pyz): 1.1200
# Final CMI: 0.0463
#
# Components contributing to CMI:
# Mean(log_pxyz): 0.6530
# Mean(log_pz): 0.5133
# Mean(log_pxz): 0.5572
# Mean(log_pyz): 0.5628
# CMI = 0.6530 + 0.5133 - 0.5572 - 0.5628 = 0.0463
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 104
# Dimensionality of threshold matrix: (104, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# Using bandwidth: 0.2686
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.3345
# Mean(log_pxz + log_pyz): -0.3817
# Final Threshold CMI: 0.0472
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of NDT matrix: (104, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.2686
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.5006
# Mean(log_pxz + log_pyz): 1.4389
# Final NDT CMI: 0.0617
# Permutation test p-value: 0.0000
# Summary of Results:
#
# Bandwidth: 0.0895
# Raw MI: 0.2340 bits
# Threshold-only retention: 141.3% (p=0.0000)
# NDT-only retention: 105.7% (p=0.0000)
# All parameters retention: 129.2% (p=0.0000)
#
# Bandwidth: 0.1343
# Raw MI: 0.2007 bits
# Threshold-only retention: 87.4% (p=0.0000)
# NDT-only retention: 85.9% (p=0.0000)
# All parameters retention: 84.7% (p=0.0000)
#
# Bandwidth: 0.1791
# Raw MI: 0.1772 bits
# Threshold-only retention: 60.6% (p=0.0000)
# NDT-only retention: 71.6% (p=0.0000)
# All parameters retention: 58.9% (p=0.0000)
#
# Bandwidth: 0.2239
# Raw MI: 0.1579 bits
# Threshold-only retention: 44.6% (p=0.0000)
# NDT-only retention: 56.8% (p=0.0000)
# All parameters retention: 43.5% (p=0.0000)
#
# Bandwidth: 0.2686
# Raw MI: 0.1435 bits
# Threshold-only retention: 32.9% (p=0.0000)
# NDT-only retention: 43.0% (p=0.0000)
# All parameters retention: 32.2% (p=0.0000)
#
# Analyzing bandwidth: 0.0895
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1343
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1791
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.2239
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.2686
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...

# %%
import NewMI_First

# Load your data
session1_path = 'Model2 LDT RMT/EZ_lexical_decision_part1_transformed.csv'  # replace with your actual path
session2_path = 'Model2 LDT RMT/EZ_lexical_decision_part2_transformed.csv'
df_merged = NewMI_First.load_and_merge(session1_path, session2_path)

analyzer = NewMI_First.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Define a range of bandwidths to test
# Using a logarithmic scale to better explore the parameter space
base_bandwidth = np.std(analyzer.data['alpha_s1'].values) * (4/(3*len(analyzer.data)))**(1/5)
bandwidths = [
    base_bandwidth * 1.0,  # Original Silverman's rule
    base_bandwidth * 1.5,  # 1.5x Silverman
    base_bandwidth * 2.0,  # 2x Silverman
    base_bandwidth * 2.5,  # 2.5x Silverman
    base_bandwidth * 3.0   # 3x Silverman
]

print(f"Base bandwidth (Silverman's rule): {base_bandwidth:.4f}")
print(f"Testing bandwidths: {[f'{bw:.4f}' for bw in bandwidths]}")

# Set verbose output to False to reduce output clutter
import warnings
warnings.filterwarnings('ignore')

# Run the bandwidth sensitivity analysis for conditional MI
bandwidth_results = analyzer.conditional_mi_bandwidth_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,  # Shrinkage parameter
    dataset_name="LDT Model 2"
)

# The method automatically produces plots, but we can also print some key results
print("\nSummary of Results:")
for i, bw in enumerate(bandwidth_results['bandwidths']):
    print(f"\nBandwidth: {bw:.4f}")
    print(f"Raw MI: {bandwidth_results['raw_mi'][i]:.4f} bits")
    
    if 'retention_threshold' in bandwidth_results:
        print(f"Threshold-only retention: {bandwidth_results['retention_threshold'][i]:.1f}% (p={bandwidth_results['p_values_threshold'][i]:.4f})")
    
    if 'retention_ndt' in bandwidth_results:
        print(f"NDT-only retention: {bandwidth_results['retention_ndt'][i]:.1f}% (p={bandwidth_results['p_values_ndt'][i]:.4f})")
    
    if 'retention_all' in bandwidth_results:
        print(f"All parameters retention: {bandwidth_results['retention_all'][i]:.1f}% (p={bandwidth_results['p_values_all'][i]:.4f})")

# Run the individual parameter analysis
individual_results = analyzer.individual_parameter_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,
    dataset_name="LDT Model 2"
)
# Out:
# Available columns in session 1: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s1', 'ndt_mean_s1', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s2', 'ndt_mean_s2', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: participant_ID
# Base bandwidth (Silverman's rule): 0.0930
# Testing bandwidths: ['0.0930', '0.1394', '0.1859', '0.2324', '0.2789']
#
# Analyzing bandwidth: 0.0930
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of control matrix: (101, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# a_mean_s1 - ndt_mean_s1: r = -0.2021
# a_mean_s1 - ndt_mean_s2: r = -0.0235
# a_mean_s2 - ndt_mean_s1: r = 0.0637
# a_mean_s2 - ndt_mean_s2: r = -0.2909
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.0930
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0910, std = 0.5089
# log_py: mean = 0.1505, std = 0.5073
# log_pz: mean = 2.7506, std = 0.7979
# log_pxz: mean = 3.5045, std = 0.5413
# log_pyz: mean = 3.5159, std = 0.5742
# log_pxyz: mean = 4.5820, std = 0.3533
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 7.3326
# Mean(log_pxz + log_pyz): 7.0204
# Final CMI: 0.3122
#
# Components contributing to CMI:
# Mean(log_pxyz): 4.5820
# Mean(log_pz): 2.7506
# Mean(log_pxz): 3.5045
# Mean(log_pyz): 3.5159
# CMI = 4.5820 + 2.7506 - 3.5045 - 3.5159 = 0.3122
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 101
# Dimensionality of threshold matrix: (101, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# Using bandwidth: 0.0930
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.8588
# Mean(log_pxz + log_pyz): 1.4942
# Final Threshold CMI: 0.3646
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of NDT matrix: (101, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.0930
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 5.5998
# Mean(log_pxz + log_pyz): 5.2986
# Final NDT CMI: 0.3012
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1394
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of control matrix: (101, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# a_mean_s1 - ndt_mean_s1: r = -0.2021
# a_mean_s1 - ndt_mean_s2: r = -0.0235
# a_mean_s2 - ndt_mean_s1: r = 0.0637
# a_mean_s2 - ndt_mean_s2: r = -0.2909
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.1394
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0662, std = 0.4357
# log_py: mean = 0.1208, std = 0.4247
# log_pz: mean = 1.8366, std = 0.9176
# log_pxz: mean = 2.2416, std = 0.7762
# log_pyz: mean = 2.2804, std = 0.7949
# log_pxyz: mean = 2.8734, std = 0.6495
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 4.7100
# Mean(log_pxz + log_pyz): 4.5220
# Final CMI: 0.1880
#
# Components contributing to CMI:
# Mean(log_pxyz): 2.8734
# Mean(log_pz): 1.8366
# Mean(log_pxz): 2.2416
# Mean(log_pyz): 2.2804
# CMI = 2.8734 + 1.8366 - 2.2416 - 2.2804 = 0.1880
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 101
# Dimensionality of threshold matrix: (101, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# Using bandwidth: 0.1394
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.7549
# Mean(log_pxz + log_pyz): 0.5467
# Final Threshold CMI: 0.2082
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of NDT matrix: (101, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.1394
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 4.2068
# Mean(log_pxz + log_pyz): 3.9871
# Final NDT CMI: 0.2197
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1859
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of control matrix: (101, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# a_mean_s1 - ndt_mean_s1: r = -0.2021
# a_mean_s1 - ndt_mean_s2: r = -0.0235
# a_mean_s2 - ndt_mean_s1: r = 0.0637
# a_mean_s2 - ndt_mean_s2: r = -0.2909
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.1859
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0289, std = 0.3610
# log_py: mean = 0.0773, std = 0.3446
# log_pz: mean = 1.1661, std = 0.9437
# log_pxz: mean = 1.3923, std = 0.8594
# log_pyz: mean = 1.4405, std = 0.8742
# log_pxyz: mean = 1.7918, std = 0.7948
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.9580
# Mean(log_pxz + log_pyz): 2.8327
# Final CMI: 0.1252
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.7918
# Mean(log_pz): 1.1661
# Mean(log_pxz): 1.3923
# Mean(log_pyz): 1.4405
# CMI = 1.7918 + 1.1661 - 1.3923 - 1.4405 = 0.1252
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 101
# Dimensionality of threshold matrix: (101, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# Using bandwidth: 0.1859
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.0811
# Mean(log_pxz + log_pyz): -0.0550
# Final Threshold CMI: 0.1362
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of NDT matrix: (101, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.1859
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.0712
# Mean(log_pxz + log_pyz): 2.9113
# Final NDT CMI: 0.1598
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.2324
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of control matrix: (101, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# a_mean_s1 - ndt_mean_s1: r = -0.2021
# a_mean_s1 - ndt_mean_s2: r = -0.0235
# a_mean_s2 - ndt_mean_s1: r = 0.0637
# a_mean_s2 - ndt_mean_s2: r = -0.2909
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.2324
#
# Summary statistics of log probabilities:
# log_px: mean = -0.0213, std = 0.2957
# log_py: mean = 0.0208, std = 0.2782
# log_pz: mean = 0.6159, std = 0.9272
# log_pxz: mean = 0.7139, std = 0.8800
# log_pyz: mean = 0.7640, std = 0.8889
# log_pxyz: mean = 0.9518, std = 0.8475
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.5678
# Mean(log_pxz + log_pyz): 1.4779
# Final CMI: 0.0899
#
# Components contributing to CMI:
# Mean(log_pxyz): 0.9518
# Mean(log_pz): 0.6159
# Mean(log_pxz): 0.7139
# Mean(log_pyz): 0.7640
# CMI = 0.9518 + 0.6159 - 0.7139 - 0.7640 = 0.0899
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 101
# Dimensionality of threshold matrix: (101, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# Using bandwidth: 0.2324
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.4635
# Mean(log_pxz + log_pyz): -0.5603
# Final Threshold CMI: 0.0967
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of NDT matrix: (101, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.2324
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.1042
# Mean(log_pxz + log_pyz): 1.9917
# Final NDT CMI: 0.1126
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.2789
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of control matrix: (101, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# a_mean_s1 - ndt_mean_s1: r = -0.2021
# a_mean_s1 - ndt_mean_s2: r = -0.0235
# a_mean_s2 - ndt_mean_s1: r = 0.0637
# a_mean_s2 - ndt_mean_s2: r = -0.2909
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.2789
#
# Summary statistics of log probabilities:
# log_px: mean = -0.0807, std = 0.2421
# log_py: mean = -0.0446, std = 0.2253
# log_pz: mean = 0.1430, std = 0.8857
# log_pxz: mean = 0.1347, std = 0.8647
# log_pyz: mean = 0.1819, std = 0.8708
# log_pxyz: mean = 0.2398, std = 0.8513
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.3829
# Mean(log_pxz + log_pyz): 0.3165
# Final CMI: 0.0663
#
# Components contributing to CMI:
# Mean(log_pxyz): 0.2398
# Mean(log_pz): 0.1430
# Mean(log_pxz): 0.1347
# Mean(log_pyz): 0.1819
# CMI = 0.2398 + 0.1430 - 0.1347 - 0.1819 = 0.0663
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 101
# Dimensionality of threshold matrix: (101, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# Using bandwidth: 0.2789
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.9499
# Mean(log_pxz + log_pyz): -1.0204
# Final Threshold CMI: 0.0705
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of NDT matrix: (101, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.2789
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.2619
# Mean(log_pxz + log_pyz): 1.1839
# Final NDT CMI: 0.0780
# Permutation test p-value: 0.0000
# Summary of Results:
#
# Bandwidth: 0.0930
# Raw MI: 0.3326 bits
# Threshold-only retention: 109.6% (p=0.0000)
# NDT-only retention: 90.6% (p=0.0000)
# All parameters retention: 93.9% (p=0.0000)
#
# Bandwidth: 0.1394
# Raw MI: 0.2872 bits
# Threshold-only retention: 72.5% (p=0.0000)
# NDT-only retention: 76.5% (p=0.0000)
# All parameters retention: 65.5% (p=0.0000)
#
# Bandwidth: 0.1859
# Raw MI: 0.2526 bits
# Threshold-only retention: 53.9% (p=0.0000)
# NDT-only retention: 63.3% (p=0.0000)
# All parameters retention: 49.6% (p=0.0000)
#
# Bandwidth: 0.2324
# Raw MI: 0.2261 bits
# Threshold-only retention: 42.8% (p=0.0000)
# NDT-only retention: 49.8% (p=0.0000)
# All parameters retention: 39.7% (p=0.0000)
#
# Bandwidth: 0.2789
# Raw MI: 0.2073 bits
# Threshold-only retention: 34.0% (p=0.0000)
# NDT-only retention: 37.6% (p=0.0000)
# All parameters retention: 32.0% (p=0.0000)
#
# Analyzing bandwidth: 0.0930
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1394
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1859
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.2324
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.2789
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...

# %%
import NewMI_First

# Load your data
session1_path = 'Model1 ELP/Transformed_recoverd_param_ELP_S1_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'
session2_path = 'Model1 ELP/Transformed_recoverd_param_ELP_S2_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'

df_merged = NewMI_First.load_and_merge(session1_path, session2_path)

# Initialize analyzer
analyzer = NewMI_First.MutualInformationAnalyzer(df_merged)



# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Define a range of bandwidths to test
# Using a logarithmic scale to better explore the parameter space
base_bandwidth = np.std(analyzer.data['alpha_s1'].values) * (4/(3*len(analyzer.data)))**(1/5)
bandwidths = [
    base_bandwidth * 1.0,  # Original Silverman's rule
    base_bandwidth * 1.5,  # 1.5x Silverman
    base_bandwidth * 2.0,  # 2x Silverman
    base_bandwidth * 2.5,  # 2.5x Silverman
    base_bandwidth * 3.0   # 3x Silverman
]

print(f"Base bandwidth (Silverman's rule): {base_bandwidth:.4f}")
print(f"Testing bandwidths: {[f'{bw:.4f}' for bw in bandwidths]}")

# Set verbose output to False to reduce output clutter
import warnings
warnings.filterwarnings('ignore')

# Run the bandwidth sensitivity analysis for conditional MI
bandwidth_results = analyzer.conditional_mi_bandwidth_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,  # Shrinkage parameter
    dataset_name="ELP Model 1"
)

# The method automatically produces plots, but we can also print some key results
print("\nSummary of Results:")
for i, bw in enumerate(bandwidth_results['bandwidths']):
    print(f"\nBandwidth: {bw:.4f}")
    print(f"Raw MI: {bandwidth_results['raw_mi'][i]:.4f} bits")
    
    if 'retention_threshold' in bandwidth_results:
        print(f"Threshold-only retention: {bandwidth_results['retention_threshold'][i]:.1f}% (p={bandwidth_results['p_values_threshold'][i]:.4f})")
    
    if 'retention_ndt' in bandwidth_results:
        print(f"NDT-only retention: {bandwidth_results['retention_ndt'][i]:.1f}% (p={bandwidth_results['p_values_ndt'][i]:.4f})")
    
    if 'retention_all' in bandwidth_results:
        print(f"All parameters retention: {bandwidth_results['retention_all'][i]:.1f}% (p={bandwidth_results['p_values_all'][i]:.4f})")

# Run the individual parameter analysis
individual_results = analyzer.individual_parameter_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,
    dataset_name="ELP Model 1"
)
# Out:
# Available columns in session 1: ['Unnamed: 0', 'participant', 'v1', 'v2', 'zr', 'a_mean_s1', 'ndt_mean_s1', 'sndt', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'participant', 'v1', 'v2', 'zr', 'a_mean_s2', 'ndt_mean_s2', 'sndt', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Using identifier column: participant
# Base bandwidth (Silverman's rule): 0.0782
# Testing bandwidths: ['0.0782', '0.1173', '0.1563', '0.1954', '0.2345']
#
# Analyzing bandwidth: 0.0782
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# a_mean_s1 - ndt_mean_s1: r = 0.2302
# a_mean_s1 - ndt_mean_s2: r = 0.2305
# a_mean_s2 - ndt_mean_s1: r = 0.2223
# a_mean_s2 - ndt_mean_s2: r = 0.3294
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.0782
#
# Summary statistics of log probabilities:
# log_px: mean = -0.0418, std = 0.6580
# log_py: mean = -0.0100, std = 0.6935
# log_pz: mean = 2.6009, std = 1.1167
# log_pxz: mean = 3.2131, std = 0.9944
# log_pyz: mean = 3.2331, std = 1.0129
# log_pxyz: mean = 4.2008, std = 0.8206
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 6.8017
# Mean(log_pxz + log_pyz): 6.4462
# Final CMI: 0.3555
#
# Components contributing to CMI:
# Mean(log_pxyz): 4.2008
# Mean(log_pz): 2.6009
# Mean(log_pxz): 3.2131
# Mean(log_pyz): 3.2331
# CMI = 4.2008 + 2.6009 - 3.2131 - 3.2331 = 0.3555
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 806
# Dimensionality of threshold matrix: (806, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# Using bandwidth: 0.0782
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.4678
# Mean(log_pxz + log_pyz): 1.0857
# Final Threshold CMI: 0.3822
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of NDT matrix: (806, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.0782
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 4.9122
# Mean(log_pxz + log_pyz): 4.5928
# Final NDT CMI: 0.3194
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1173
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# a_mean_s1 - ndt_mean_s1: r = 0.2302
# a_mean_s1 - ndt_mean_s2: r = 0.2305
# a_mean_s2 - ndt_mean_s1: r = 0.2223
# a_mean_s2 - ndt_mean_s2: r = 0.3294
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.1173
#
# Summary statistics of log probabilities:
# log_px: mean = -0.0669, std = 0.6253
# log_py: mean = -0.0300, std = 0.6513
# log_pz: mean = 1.9353, std = 1.0590
# log_pxz: mean = 2.2784, std = 1.1115
# log_pyz: mean = 2.2820, std = 1.1425
# log_pxyz: mean = 2.8396, std = 1.1143
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 4.7749
# Mean(log_pxz + log_pyz): 4.5604
# Final CMI: 0.2145
#
# Components contributing to CMI:
# Mean(log_pxyz): 2.8396
# Mean(log_pz): 1.9353
# Mean(log_pxz): 2.2784
# Mean(log_pyz): 2.2820
# CMI = 2.8396 + 1.9353 - 2.2784 - 2.2820 = 0.2145
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 806
# Dimensionality of threshold matrix: (806, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# Using bandwidth: 0.1173
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.7297
# Mean(log_pxz + log_pyz): 0.5056
# Final Threshold CMI: 0.2241
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of NDT matrix: (806, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.1173
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.8925
# Mean(log_pxz + log_pyz): 3.6679
# Final NDT CMI: 0.2246
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1563
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# a_mean_s1 - ndt_mean_s1: r = 0.2302
# a_mean_s1 - ndt_mean_s2: r = 0.2305
# a_mean_s2 - ndt_mean_s1: r = 0.2223
# a_mean_s2 - ndt_mean_s2: r = 0.3294
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.1563
#
# Summary statistics of log probabilities:
# log_px: mean = -0.0951, std = 0.5834
# log_py: mean = -0.0566, std = 0.5980
# log_pz: mean = 1.3978, std = 0.9486
# log_pxz: mean = 1.6031, std = 1.0769
# log_pyz: mean = 1.6004, std = 1.1064
# log_pxyz: mean = 1.9513, std = 1.1666
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.3490
# Mean(log_pxz + log_pyz): 3.2035
# Final CMI: 0.1456
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.9513
# Mean(log_pz): 1.3978
# Mean(log_pxz): 1.6031
# Mean(log_pyz): 1.6004
# CMI = 1.9513 + 1.3978 - 1.6031 - 1.6004 = 0.1456
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 806
# Dimensionality of threshold matrix: (806, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# Using bandwidth: 0.1563
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.2096
# Mean(log_pxz + log_pyz): 0.0562
# Final Threshold CMI: 0.1535
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of NDT matrix: (806, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.1563
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.0359
# Mean(log_pxz + log_pyz): 2.8547
# Final NDT CMI: 0.1812
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1954
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# a_mean_s1 - ndt_mean_s1: r = 0.2302
# a_mean_s1 - ndt_mean_s2: r = 0.2305
# a_mean_s2 - ndt_mean_s1: r = 0.2223
# a_mean_s2 - ndt_mean_s2: r = 0.3294
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.1954
#
# Summary statistics of log probabilities:
# log_px: mean = -0.1293, std = 0.5377
# log_py: mean = -0.0913, std = 0.5426
# log_pz: mean = 0.9275, std = 0.8499
# log_pxz: mean = 1.0300, std = 1.0091
# log_pyz: mean = 1.0292, std = 1.0253
# log_pxyz: mean = 1.2401, std = 1.1276
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.1676
# Mean(log_pxz + log_pyz): 2.0592
# Final CMI: 0.1084
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.2401
# Mean(log_pz): 0.9275
# Mean(log_pxz): 1.0300
# Mean(log_pyz): 1.0292
# CMI = 1.2401 + 0.9275 - 1.0300 - 1.0292 = 0.1084
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 806
# Dimensionality of threshold matrix: (806, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# Using bandwidth: 0.1954
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.2428
# Mean(log_pxz + log_pyz): -0.3575
# Final Threshold CMI: 0.1148
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of NDT matrix: (806, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.1954
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.2670
# Mean(log_pxz + log_pyz): 2.1169
# Final NDT CMI: 0.1501
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.2345
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# a_mean_s1 - ndt_mean_s1: r = 0.2302
# a_mean_s1 - ndt_mean_s2: r = 0.2305
# a_mean_s2 - ndt_mean_s1: r = 0.2223
# a_mean_s2 - ndt_mean_s2: r = 0.3294
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.2345
#
# Summary statistics of log probabilities:
# log_px: mean = -0.1683, std = 0.4892
# log_py: mean = -0.1318, std = 0.4865
# log_pz: mean = 0.5063, std = 0.7699
# log_pxz: mean = 0.5203, std = 0.9355
# log_pyz: mean = 0.5247, std = 0.9352
# log_pxyz: mean = 0.6229, std = 1.0560
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.1292
# Mean(log_pxz + log_pyz): 1.0450
# Final CMI: 0.0842
#
# Components contributing to CMI:
# Mean(log_pxyz): 0.6229
# Mean(log_pz): 0.5063
# Mean(log_pxz): 0.5203
# Mean(log_pyz): 0.5247
# CMI = 0.6229 + 0.5063 - 0.5203 - 0.5247 = 0.0842
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 806
# Dimensionality of threshold matrix: (806, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# Using bandwidth: 0.2345
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.6602
# Mean(log_pxz + log_pyz): -0.7495
# Final Threshold CMI: 0.0892
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of NDT matrix: (806, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.2345
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.5689
# Mean(log_pxz + log_pyz): 1.4451
# Final NDT CMI: 0.1239
# Permutation test p-value: 0.0000
# Summary of Results:
#
# Bandwidth: 0.0782
# Raw MI: 0.2623 bits
# Threshold-only retention: 145.7% (p=0.0000)
# NDT-only retention: 121.8% (p=0.0000)
# All parameters retention: 135.6% (p=0.0000)
#
# Bandwidth: 0.1173
# Raw MI: 0.2397 bits
# Threshold-only retention: 93.5% (p=0.0000)
# NDT-only retention: 93.7% (p=0.0000)
# All parameters retention: 89.5% (p=0.0000)
#
# Bandwidth: 0.1563
# Raw MI: 0.2204 bits
# Threshold-only retention: 69.6% (p=0.0000)
# NDT-only retention: 82.2% (p=0.0000)
# All parameters retention: 66.1% (p=0.0000)
#
# Bandwidth: 0.1954
# Raw MI: 0.2032 bits
# Threshold-only retention: 56.5% (p=0.0000)
# NDT-only retention: 73.9% (p=0.0000)
# All parameters retention: 53.3% (p=0.0000)
#
# Bandwidth: 0.2345
# Raw MI: 0.1883 bits
# Threshold-only retention: 47.4% (p=0.0000)
# NDT-only retention: 65.8% (p=0.0000)
# All parameters retention: 44.7% (p=0.0000)
#
# Analyzing bandwidth: 0.0782
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1173
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1563
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1954
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.2345
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...

# %% [markdown]
# # ELP Model 2

# %%
import NewMI_First

# Load your data
session1_path = 'Model2 ELP/Transformed_recoverd_param_ELP_S1_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'
session2_path = 'Model2 ELP/Transformed_recoverd_param_ELP_S2_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'

df_merged = NewMI_First.load_and_merge(session1_path, session2_path)

analyzer = NewMI_First.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Define a range of bandwidths to test
# Using a logarithmic scale to better explore the parameter space
base_bandwidth = np.std(analyzer.data['alpha_s1'].values) * (4/(3*len(analyzer.data)))**(1/5)
bandwidths = [
    base_bandwidth * 1.0,  # Original Silverman's rule
    base_bandwidth * 1.5,  # 1.5x Silverman
    base_bandwidth * 2.0,  # 2x Silverman
    base_bandwidth * 2.5,  # 2.5x Silverman
    base_bandwidth * 3.0   # 3x Silverman
]

print(f"Base bandwidth (Silverman's rule): {base_bandwidth:.4f}")
print(f"Testing bandwidths: {[f'{bw:.4f}' for bw in bandwidths]}")

# Set verbose output to False to reduce output clutter
import warnings
warnings.filterwarnings('ignore')

# Run the bandwidth sensitivity analysis for conditional MI
bandwidth_results = analyzer.conditional_mi_bandwidth_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,  # Shrinkage parameter
    dataset_name="ELP Model 2"
)

# The method automatically produces plots, but we can also print some key results
print("\nSummary of Results:")
for i, bw in enumerate(bandwidth_results['bandwidths']):
    print(f"\nBandwidth: {bw:.4f}")
    print(f"Raw MI: {bandwidth_results['raw_mi'][i]:.4f} bits")
    
    if 'retention_threshold' in bandwidth_results:
        print(f"Threshold-only retention: {bandwidth_results['retention_threshold'][i]:.1f}% (p={bandwidth_results['p_values_threshold'][i]:.4f})")
    
    if 'retention_ndt' in bandwidth_results:
        print(f"NDT-only retention: {bandwidth_results['retention_ndt'][i]:.1f}% (p={bandwidth_results['p_values_ndt'][i]:.4f})")
    
    if 'retention_all' in bandwidth_results:
        print(f"All parameters retention: {bandwidth_results['retention_all'][i]:.1f}% (p={bandwidth_results['p_values_all'][i]:.4f})")

# Run the individual parameter analysis
individual_results = analyzer.individual_parameter_sensitivity(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    bandwidths=bandwidths,
    alpha=0.5,
    dataset_name="ELP Model 2"
)
# Out:
# Available columns in session 1: ['Unnamed: 0', 'participant', 'v1', 'v2', 'a_mean_s1', 'ndt_mean_s1', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'participant', 'v1', 'v2', 'a_mean_s2', 'ndt_mean_s2', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Using identifier column: participant
# Base bandwidth (Silverman's rule): 0.0747
# Testing bandwidths: ['0.0747', '0.1120', '0.1493', '0.1867', '0.2240']
#
# Analyzing bandwidth: 0.0747
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# a_mean_s1 - ndt_mean_s1: r = -0.0790
# a_mean_s1 - ndt_mean_s2: r = -0.0015
# a_mean_s2 - ndt_mean_s1: r = 0.0361
# a_mean_s2 - ndt_mean_s2: r = -0.1414
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.0747
#
# Summary statistics of log probabilities:
# log_px: mean = -0.1011, std = 0.6624
# log_py: mean = -0.1127, std = 0.6866
# log_pz: mean = 2.2375, std = 1.2008
# log_pxz: mean = 3.0752, std = 0.9810
# log_pyz: mean = 3.0616, std = 0.9961
# log_pxyz: mean = 4.2365, std = 0.7545
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 6.4740
# Mean(log_pxz + log_pyz): 6.1368
# Final CMI: 0.3372
#
# Components contributing to CMI:
# Mean(log_pxyz): 4.2365
# Mean(log_pz): 2.2375
# Mean(log_pxz): 3.0752
# Mean(log_pyz): 3.0616
# CMI = 4.2365 + 2.2375 - 3.0752 - 3.0616 = 0.3372
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 806
# Dimensionality of threshold matrix: (806, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# Using bandwidth: 0.0747
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.7388
# Mean(log_pxz + log_pyz): 0.2586
# Final Threshold CMI: 0.4802
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of NDT matrix: (806, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.0747
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 5.0135
# Mean(log_pxz + log_pyz): 4.5285
# Final NDT CMI: 0.4850
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1120
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# a_mean_s1 - ndt_mean_s1: r = -0.0790
# a_mean_s1 - ndt_mean_s2: r = -0.0015
# a_mean_s2 - ndt_mean_s1: r = 0.0361
# a_mean_s2 - ndt_mean_s2: r = -0.1414
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.1120
#
# Summary statistics of log probabilities:
# log_px: mean = -0.1082, std = 0.6150
# log_py: mean = -0.1209, std = 0.6449
# log_pz: mean = 1.5293, std = 1.2642
# log_pxz: mean = 2.0268, std = 1.2309
# log_pyz: mean = 1.9963, std = 1.2550
# log_pxyz: mean = 2.7427, std = 1.1562
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 4.2721
# Mean(log_pxz + log_pyz): 4.0231
# Final CMI: 0.2489
#
# Components contributing to CMI:
# Mean(log_pxyz): 2.7427
# Mean(log_pz): 1.5293
# Mean(log_pxz): 2.0268
# Mean(log_pyz): 1.9963
# CMI = 2.7427 + 1.5293 - 2.0268 - 1.9963 = 0.2489
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 806
# Dimensionality of threshold matrix: (806, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# Using bandwidth: 0.1120
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.0724
# Mean(log_pxz + log_pyz): -0.3984
# Final Threshold CMI: 0.3259
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of NDT matrix: (806, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.1120
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.9888
# Mean(log_pxz + log_pyz): 3.6356
# Final NDT CMI: 0.3532
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1493
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# a_mean_s1 - ndt_mean_s1: r = -0.0790
# a_mean_s1 - ndt_mean_s2: r = -0.0015
# a_mean_s2 - ndt_mean_s1: r = 0.0361
# a_mean_s2 - ndt_mean_s2: r = -0.1414
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.1493
#
# Summary statistics of log probabilities:
# log_px: mean = -0.1196, std = 0.5559
# log_py: mean = -0.1326, std = 0.5881
# log_pz: mean = 1.0121, std = 1.2144
# log_pxz: mean = 1.3188, std = 1.2861
# log_pyz: mean = 1.2908, std = 1.3051
# log_pxyz: mean = 1.7849, std = 1.3102
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.7971
# Mean(log_pxz + log_pyz): 2.6096
# Final CMI: 0.1875
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.7849
# Mean(log_pz): 1.0121
# Mean(log_pxz): 1.3188
# Mean(log_pyz): 1.2908
# CMI = 1.7849 + 1.0121 - 1.3188 - 1.2908 = 0.1875
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 806
# Dimensionality of threshold matrix: (806, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# Using bandwidth: 0.1493
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.5781
# Mean(log_pxz + log_pyz): -0.8105
# Final Threshold CMI: 0.2324
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of NDT matrix: (806, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.1493
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.1379
# Mean(log_pxz + log_pyz): 2.8621
# Final NDT CMI: 0.2758
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.1867
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# a_mean_s1 - ndt_mean_s1: r = -0.0790
# a_mean_s1 - ndt_mean_s2: r = -0.0015
# a_mean_s2 - ndt_mean_s1: r = 0.0361
# a_mean_s2 - ndt_mean_s2: r = -0.1414
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.1867
#
# Summary statistics of log probabilities:
# log_px: mean = -0.1375, std = 0.4930
# log_py: mean = -0.1500, std = 0.5246
# log_pz: mean = 0.5793, std = 1.1407
# log_pxz: mean = 0.7536, std = 1.2588
# log_pyz: mean = 0.7306, std = 1.2752
# log_pxyz: mean = 1.0499, std = 1.3368
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.6291
# Mean(log_pxz + log_pyz): 1.4842
# Final CMI: 0.1449
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.0499
# Mean(log_pz): 0.5793
# Mean(log_pxz): 0.7536
# Mean(log_pyz): 0.7306
# CMI = 1.0499 + 0.5793 - 0.7536 - 0.7306 = 0.1449
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 806
# Dimensionality of threshold matrix: (806, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# Using bandwidth: 0.1867
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -0.9797
# Mean(log_pxz + log_pyz): -1.1520
# Final Threshold CMI: 0.1724
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of NDT matrix: (806, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.1867
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.3869
# Mean(log_pxz + log_pyz): 2.1662
# Final NDT CMI: 0.2206
# Permutation test p-value: 0.0000
#
# Analyzing bandwidth: 0.2240
# Calculating conditional MI for all parameters...
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# a_mean_s1 - ndt_mean_s1: r = -0.0790
# a_mean_s1 - ndt_mean_s2: r = -0.0015
# a_mean_s2 - ndt_mean_s1: r = 0.0361
# a_mean_s2 - ndt_mean_s2: r = -0.1414
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.2240
#
# Summary statistics of log probabilities:
# log_px: mean = -0.1623, std = 0.4318
# log_py: mean = -0.1740, std = 0.4610
# log_pz: mean = 0.1977, std = 1.0660
# log_pxz: mean = 0.2692, std = 1.1972
# log_pyz: mean = 0.2499, std = 1.2133
# log_pxyz: mean = 0.4353, std = 1.3008
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 0.6330
# Mean(log_pxz + log_pyz): 0.5191
# Final CMI: 0.1139
#
# Components contributing to CMI:
# Mean(log_pxyz): 0.4353
# Mean(log_pz): 0.1977
# Mean(log_pxz): 0.2692
# Mean(log_pyz): 0.2499
# CMI = 0.4353 + 0.1977 - 0.2692 - 0.2499 = 0.1139
# Permutation test p-value: 0.0000
# Calculating conditional MI for threshold parameters...
#
# Diagnostic Information for Conditional MI (Threshold Parameters):
# Number of threshold variables: 2
# Threshold variables: ['a_mean_s1', 'a_mean_s2']
# Sample size: 806
# Dimensionality of threshold matrix: (806, 2)
#
# Correlations between threshold variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# Using bandwidth: 0.2240
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): -1.3347
# Mean(log_pxz + log_pyz): -1.4658
# Final Threshold CMI: 0.1311
# Permutation test p-value: 0.0000
# Calculating conditional MI for NDT parameters...
#
# Diagnostic Information for Conditional MI (NDT Parameters):
# Number of NDT variables: 2
# NDT variables: ['ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of NDT matrix: (806, 2)
#
# Correlations between NDT variables:
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.2240
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.7091
# Mean(log_pxz + log_pyz): 1.5330
# Final NDT CMI: 0.1761
# Permutation test p-value: 0.0000
# Summary of Results:
#
# Bandwidth: 0.0747
# Raw MI: 0.3811 bits
# Threshold-only retention: 126.0% (p=0.0000)
# NDT-only retention: 127.3% (p=0.0000)
# All parameters retention: 88.5% (p=0.0000)
#
# Bandwidth: 0.1120
# Raw MI: 0.3431 bits
# Threshold-only retention: 95.0% (p=0.0000)
# NDT-only retention: 102.9% (p=0.0000)
# All parameters retention: 72.6% (p=0.0000)
#
# Bandwidth: 0.1493
# Raw MI: 0.3092 bits
# Threshold-only retention: 75.2% (p=0.0000)
# NDT-only retention: 89.2% (p=0.0000)
# All parameters retention: 60.6% (p=0.0000)
#
# Bandwidth: 0.1867
# Raw MI: 0.2790 bits
# Threshold-only retention: 61.8% (p=0.0000)
# NDT-only retention: 79.1% (p=0.0000)
# All parameters retention: 52.0% (p=0.0000)
#
# Bandwidth: 0.2240
# Raw MI: 0.2532 bits
# Threshold-only retention: 51.8% (p=0.0000)
# NDT-only retention: 69.5% (p=0.0000)
# All parameters retention: 45.0% (p=0.0000)
#
# Analyzing bandwidth: 0.0747
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1120
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1493
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.1867
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
#
# Analyzing bandwidth: 0.2240
# Calculating conditional MI for a_mean_s1...
# Calculating conditional MI for a_mean_s2...
# Calculating conditional MI for ndt_mean_s1...
# Calculating conditional MI for ndt_mean_s2...
