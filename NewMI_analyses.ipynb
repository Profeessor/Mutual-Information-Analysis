# %%
import NewMI

# Load your data
session1_path = 'Model2 LDT RMT/EZ_recognition_memory_part1_transformed.csv'  # replace with your actual path
session2_path = 'Model2 LDT RMT/EZ_recognition_memory_part2_transformed.csv'
df_merged = NewMI.load_and_merge(session1_path, session2_path)

# Initialize analyzer
analyzer = NewMI.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Run analysis
results = analyzer.analyze_alpha_reliability(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    primary_method='shrinkage_mi'  # Use this method for calculations
)

# Print results
print("\nRaw Mutual Information Estimates:")
print(f"Gaussian MI: {results['gaussian_mi'][0]:.4f} bits (p={results['gaussian_mi'][1]:.4f})")
print(f"Adaptive Binning MI: {results['adaptive_binning_mi'][0]:.4f} bits (p={results['adaptive_binning_mi'][1]:.4f})")
print(f"Shrinkage MI: {results['shrinkage_mi'][0]:.4f} bits (p={results['shrinkage_mi'][1]:.4f})")

print("\nConditional Mutual Information (controlling for each parameter):")
for var, (cmi, p_value) in results['conditional_mi'].items():
    print(f"{var}: {cmi:.4f} bits (p={p_value:.4f})")
    print(f"Retention: {results['retention'][var]:.1f}%")

# Plot results
analyzer.plot_results(results)
# Out:
# Available columns in session 1: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s1', 'ndt_mean_s1', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s2', 'ndt_mean_s2', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: participant_ID
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 75
# Dimensionality of control matrix: (75, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5655
# a_mean_s1 - ndt_mean_s1: r = -0.1149
# a_mean_s1 - ndt_mean_s2: r = 0.0353
# a_mean_s2 - ndt_mean_s1: r = 0.0763
# a_mean_s2 - ndt_mean_s2: r = -0.3325
# ndt_mean_s1 - ndt_mean_s2: r = 0.3387
# Using bandwidth: 0.2000
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0399, std = 0.3684
# log_py: mean = -0.0277, std = 0.3561
# log_pz: mean = 1.2013, std = 0.7267
# log_pxz: mean = 1.3705, std = 0.7493
# log_pyz: mean = 1.3349, std = 0.7090
# log_pxyz: mean = 1.5695, std = 0.7020
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.7707
# Mean(log_pxz + log_pyz): 2.7054
# Final CMI: 0.0654
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.5695
# Mean(log_pz): 1.2013
# Mean(log_pxz): 1.3705
# Mean(log_pyz): 1.3349
# CMI = 1.5695 + 1.2013 - 1.3705 - 1.3349 = 0.0654
# Permutation test p-value: 0.0002
#
# Raw Mutual Information Estimates:
# Gaussian MI: 0.0763 bits (p=0.0002)
# Adaptive Binning MI: 0.3542 bits (p=0.7736)
# Shrinkage MI: 0.0655 bits (p=0.0008)
#
# Conditional Mutual Information (controlling for each parameter):
# a_mean_s1: 0.0578 bits (p=0.0434)
# Retention: 88.2%
# a_mean_s2: 0.0477 bits (p=0.0000)
# Retention: 72.8%
# ndt_mean_s1: 0.0563 bits (p=0.0004)
# Retention: 86.0%
# ndt_mean_s2: 0.0573 bits (p=0.0002)
# Retention: 87.4%
# Mutual Information Summary (All Parameters):
# Primary Method: shrinkage_mi
# Raw MI: 0.0655 bits (p=0.0008)
# Conditional MI (all parameters): 0.0654 bits (p=0.0002)
# Overall Retention: 99.8%

# %%
import NewMI

# Load your data
session1_path = 'Model1 LDT RMT/rmt_session_1_data_transformed.csv'  # replace with your actual path
session2_path = 'Model1 LDT RMT/rmt_session_2_data_transformed.csv'
df_merged = NewMI.load_and_merge(session1_path, session2_path)

# Initialize analyzer
analyzer = NewMI.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Run analysis
results = analyzer.analyze_alpha_reliability(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    primary_method='shrinkage_mi'  # Use this method for calculations
)

# Print results
print("\nRaw Mutual Information Estimates:")
print(f"Gaussian MI: {results['gaussian_mi'][0]:.4f} bits (p={results['gaussian_mi'][1]:.4f})")
print(f"Adaptive Binning MI: {results['adaptive_binning_mi'][0]:.4f} bits (p={results['adaptive_binning_mi'][1]:.4f})")
print(f"Shrinkage MI: {results['shrinkage_mi'][0]:.4f} bits (p={results['shrinkage_mi'][1]:.4f})")

print("\nConditional Mutual Information (controlling for each parameter):")
for var, (cmi, p_value) in results['conditional_mi'].items():
    print(f"{var}: {cmi:.4f} bits (p={p_value:.4f})")
    print(f"Retention: {results['retention'][var]:.1f}%")

# Plot results
analyzer.plot_results(results)
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Available columns in session 1: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s1', 'ndt_mean_s1', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s2', 'ndt_mean_s2', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: ID
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 97
# Dimensionality of control matrix: (97, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6660
# a_mean_s1 - ndt_mean_s1: r = -0.1951
# a_mean_s1 - ndt_mean_s2: r = -0.0428
# a_mean_s2 - ndt_mean_s1: r = -0.2710
# a_mean_s2 - ndt_mean_s2: r = -0.3109
# ndt_mean_s1 - ndt_mean_s2: r = 0.4158
# Using bandwidth: 0.2000
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0582, std = 0.3374
# log_py: mean = 0.3070, std = 0.5110
# log_pz: mean = 1.0803, std = 0.7231
# log_pxz: mean = 1.2342, std = 0.7208
# log_pyz: mean = 1.4778, std = 0.8077
# log_pxyz: mean = 1.6687, std = 0.7634
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.7490
# Mean(log_pxz + log_pyz): 2.7120
# Final CMI: 0.0370
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.6687
# Mean(log_pz): 1.0803
# Mean(log_pxz): 1.2342
# Mean(log_pyz): 1.4778
# CMI = 1.6687 + 1.0803 - 1.2342 - 1.4778 = 0.0370
# Permutation test p-value: 0.0010
#
# Raw Mutual Information Estimates:
# Gaussian MI: 0.0157 bits (p=0.0860)
# Adaptive Binning MI: 0.4045 bits (p=0.5096)
# Shrinkage MI: 0.0199 bits (p=0.0484)
#
# Conditional Mutual Information (controlling for each parameter):
# a_mean_s1: 0.0289 bits (p=0.1042)
# Retention: 144.9%
# a_mean_s2: 0.0336 bits (p=0.0204)
# Retention: 168.3%
# ndt_mean_s1: 0.0246 bits (p=0.0386)
# Retention: 123.2%
# ndt_mean_s2: 0.0251 bits (p=0.0020)
# Retention: 125.9%
# Mutual Information Summary (All Parameters):
# Primary Method: shrinkage_mi
# Raw MI: 0.0199 bits (p=0.0484)
# Conditional MI (all parameters): 0.0370 bits (p=0.0010)
# Overall Retention: 185.7%

# %%
import NewMI

# Load your data
session1_path = 'Model1 LDT RMT/ldt_session_1_data_transformed.csv'  # replace with your actual path
session2_path = 'Model1 LDT RMT/ldt_session_2_data_transformed.csv'
df_merged = NewMI.load_and_merge(session1_path, session2_path)

# Initialize analyzer
analyzer = NewMI.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Run analysis
results = analyzer.analyze_alpha_reliability(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    primary_method='shrinkage_mi'  # Use this method for calculations
)

# Print results
print("\nRaw Mutual Information Estimates:")
print(f"Gaussian MI: {results['gaussian_mi'][0]:.4f} bits (p={results['gaussian_mi'][1]:.4f})")
print(f"Adaptive Binning MI: {results['adaptive_binning_mi'][0]:.4f} bits (p={results['adaptive_binning_mi'][1]:.4f})")
print(f"Shrinkage MI: {results['shrinkage_mi'][0]:.4f} bits (p={results['shrinkage_mi'][1]:.4f})")

print("\nConditional Mutual Information (controlling for each parameter):")
for var, (cmi, p_value) in results['conditional_mi'].items():
    print(f"{var}: {cmi:.4f} bits (p={p_value:.4f})")
    print(f"Retention: {results['retention'][var]:.1f}%")

# Plot results
analyzer.plot_results(results)
# Out:
# Available columns in session 1: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s1', 'ndt_mean_s1', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'Experiment', 'v1_mean', 'v2_mean', 'zr_mean', 'a_mean_s2', 'ndt_mean_s2', 'sndt_mean', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_error', 'error_array', 'RT_Cor_arr', 'ID', 'Task', 'Session', 'alpha_shifted', 'alpha_clipped', 'alpha_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: ID
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 104
# Dimensionality of control matrix: (104, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.7837
# a_mean_s1 - ndt_mean_s1: r = 0.0481
# a_mean_s1 - ndt_mean_s2: r = 0.1333
# a_mean_s2 - ndt_mean_s1: r = 0.0206
# a_mean_s2 - ndt_mean_s2: r = 0.1147
# ndt_mean_s1 - ndt_mean_s2: r = 0.4507
# Using bandwidth: 0.2000
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0399, std = 0.2991
# log_py: mean = 0.0932, std = 0.2922
# log_pz: mean = 1.3086, std = 0.7292
# log_pxz: mean = 1.5097, std = 0.7060
# log_pyz: mean = 1.5056, std = 0.7186
# log_pxyz: mean = 1.7921, std = 0.6917
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 3.1008
# Mean(log_pxz + log_pyz): 3.0153
# Final CMI: 0.0854
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.7921
# Mean(log_pz): 1.3086
# Mean(log_pxz): 1.5097
# Mean(log_pyz): 1.5056
# CMI = 1.7921 + 1.3086 - 1.5097 - 1.5056 = 0.0854
# Permutation test p-value: 0.0000
#
# Raw Mutual Information Estimates:
# Gaussian MI: 0.2246 bits (p=0.0000)
# Adaptive Binning MI: 0.6201 bits (p=0.0090)
# Shrinkage MI: 0.1676 bits (p=0.0000)
#
# Conditional Mutual Information (controlling for each parameter):
# a_mean_s1: 0.0837 bits (p=0.0000)
# Retention: 50.0%
# a_mean_s2: 0.0925 bits (p=0.0000)
# Retention: 55.2%
# ndt_mean_s1: 0.1096 bits (p=0.0000)
# Retention: 65.4%
# ndt_mean_s2: 0.1093 bits (p=0.0000)
# Retention: 65.3%
# Mutual Information Summary (All Parameters):
# Primary Method: shrinkage_mi
# Raw MI: 0.1676 bits (p=0.0000)
# Conditional MI (all parameters): 0.0854 bits (p=0.0000)
# Overall Retention: 51.0%

# %%
import NewMI

# Load your data
session1_path = 'Model2 LDT RMT/EZ_lexical_decision_part1_transformed.csv'  # replace with your actual path
session2_path = 'Model2 LDT RMT/EZ_lexical_decision_part2_transformed.csv'
df_merged = NewMI.load_and_merge(session1_path, session2_path)

# Initialize analyzer
analyzer = NewMI.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Run analysis
results = analyzer.analyze_alpha_reliability(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    primary_method='shrinkage_mi'  # Use this method for calculations
)

# Print results
print("\nRaw Mutual Information Estimates:")
print(f"Gaussian MI: {results['gaussian_mi'][0]:.4f} bits (p={results['gaussian_mi'][1]:.4f})")
print(f"Adaptive Binning MI: {results['adaptive_binning_mi'][0]:.4f} bits (p={results['adaptive_binning_mi'][1]:.4f})")
print(f"Shrinkage MI: {results['shrinkage_mi'][0]:.4f} bits (p={results['shrinkage_mi'][1]:.4f})")

print("\nConditional Mutual Information (controlling for each parameter):")
for var, (cmi, p_value) in results['conditional_mi'].items():
    print(f"{var}: {cmi:.4f} bits (p={p_value:.4f})")
    print(f"Retention: {results['retention'][var]:.1f}%")

# Plot results
analyzer.plot_results(results)
# Out:
# Available columns in session 1: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s1', 'ndt_mean_s1', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s1', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Available columns in session 2: ['Experiment', 'v1_mean', 'v2_mean', 'a_mean_s2', 'ndt_mean_s2', 'alpha_mean', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'error_array', 'RT_Cor_arr', 'q1_C', 'q2_C', 'q3_C', 'q4_C', 'q1_E', 'q2_E', 'q3_E', 'q4_E', 'participant_ID', 'alpha_mean_shifted', 'alpha_mean_arcsin', 'alpha_boxcox_after_arcsin_s2', 'accuracy_percentage_arcsin', 'accuracy_percentage_boxcox_after_arcsin']
# Using identifier column: participant_ID
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 101
# Dimensionality of control matrix: (101, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.5233
# a_mean_s1 - ndt_mean_s1: r = -0.2021
# a_mean_s1 - ndt_mean_s2: r = -0.0235
# a_mean_s2 - ndt_mean_s1: r = 0.0637
# a_mean_s2 - ndt_mean_s2: r = -0.2909
# ndt_mean_s1 - ndt_mean_s2: r = 0.4316
# Using bandwidth: 0.2000
#
# Summary statistics of log probabilities:
# log_px: mean = 0.0149, std = 0.3400
# log_py: mean = 0.0614, std = 0.3230
# log_pz: mean = 0.9895, std = 0.9424
# log_pxz: mean = 1.1736, std = 0.8704
# log_pyz: mean = 1.2230, std = 0.8835
# log_pxyz: mean = 1.5197, std = 0.8179
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.5092
# Mean(log_pxz + log_pyz): 2.3966
# Final CMI: 0.1624 bits
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.5197
# Mean(log_pz): 0.9895
# Mean(log_pxz): 1.1736
# Mean(log_pyz): 1.2230
# CMI = (1.5197 + 0.9895 - 1.1736 - 1.2230) / ln(2) = 0.1624 bits
# Permutation test p-value: 0.0002
#
# KDE Dimensionality Consistency Check:
# Minimum retention from individual controls: 56.38%
# Joint retention (all controls): 46.20%
# Ratio (joint/min individual): 0.82
#
# No major inconsistency detected between joint and individual CMI estimates.
#
# Raw Mutual Information Estimates:
# Gaussian MI: 0.4806 bits (p=0.0002)
# Adaptive Binning MI: 0.9032 bits (p=0.0106)
# Shrinkage MI: 0.3516 bits (p=0.0002)
#
# Conditional Mutual Information (controlling for each parameter):
# a_mean_s1: 0.2120 bits (p=0.0002)
# Retention: 60.3%
# a_mean_s2: 0.1982 bits (p=0.0002)
# Retention: 56.4%
# ndt_mean_s1: 0.2145 bits (p=0.0002)
# Retention: 61.0%
# ndt_mean_s2: 0.2155 bits (p=0.0002)
# Retention: 61.3%
# Mutual Information Summary (All Parameters):
# Primary Method: shrinkage_mi
# Raw MI: 0.3516 bits (p=0.0002)
# Conditional MI (all parameters): 0.1624 bits (p=0.0002)
# Overall Retention: 46.2%

# %%
import NewMI

# Load your data
session1_path = 'Model1 ELP/Transformed_recoverd_param_ELP_S1_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'
session2_path = 'Model1 ELP/Transformed_recoverd_param_ELP_S2_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'

df_merged = NewMI.load_and_merge(session1_path, session2_path)

# Initialize analyzer
analyzer = NewMI.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Run analysis
results = analyzer.analyze_alpha_reliability(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    primary_method='shrinkage_mi'  # Use this method for calculations
)

# Print results
print("\nRaw Mutual Information Estimates:")
print(f"Gaussian MI: {results['gaussian_mi'][0]:.4f} bits (p={results['gaussian_mi'][1]:.4f})")
print(f"Adaptive Binning MI: {results['adaptive_binning_mi'][0]:.4f} bits (p={results['adaptive_binning_mi'][1]:.4f})")
print(f"Shrinkage MI: {results['shrinkage_mi'][0]:.4f} bits (p={results['shrinkage_mi'][1]:.4f})")

print("\nConditional Mutual Information (controlling for each parameter):")
for var, (cmi, p_value) in results['conditional_mi'].items():
    print(f"{var}: {cmi:.4f} bits (p={p_value:.4f})")
    print(f"Retention: {results['retention'][var]:.1f}%")

# Plot results
analyzer.plot_results(results)
# Out:
# Available columns in session 1: ['Unnamed: 0', 'participant', 'v1', 'v2', 'zr', 'a_mean_s1', 'ndt_mean_s1', 'sndt', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'participant', 'v1', 'v2', 'zr', 'a_mean_s2', 'ndt_mean_s2', 'sndt', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Using identifier column: participant
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.8250
# a_mean_s1 - ndt_mean_s1: r = 0.2302
# a_mean_s1 - ndt_mean_s2: r = 0.2305
# a_mean_s2 - ndt_mean_s1: r = 0.2223
# a_mean_s2 - ndt_mean_s2: r = 0.3294
# ndt_mean_s1 - ndt_mean_s2: r = 0.6151
# Using bandwidth: 0.2000
#
# Summary statistics of log probabilities:
# log_px: mean = -0.1336, std = 0.5322
# log_py: mean = -0.0958, std = 0.5361
# log_pz: mean = 0.8759, std = 0.8397
# log_pxz: mean = 0.9675, std = 1.0006
# log_pyz: mean = 0.9673, std = 1.0148
# log_pxyz: mean = 1.1639, std = 1.1203
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 2.0398
# Mean(log_pxz + log_pyz): 1.9347
# Final CMI: 0.1051
#
# Components contributing to CMI:
# Mean(log_pxyz): 1.1639
# Mean(log_pz): 0.8759
# Mean(log_pxz): 0.9675
# Mean(log_pyz): 0.9673
# CMI = 1.1639 + 0.8759 - 0.9675 - 0.9673 = 0.1051
# Permutation test p-value: 0.0000
#
# Raw Mutual Information Estimates:
# Gaussian MI: 0.2423 bits (p=0.0000)
# Adaptive Binning MI: 0.7098 bits (p=0.0000)
# Shrinkage MI: 0.2013 bits (p=0.0000)
#
# Conditional Mutual Information (controlling for each parameter):
# a_mean_s1: 0.1097 bits (p=0.0000)
# Retention: 54.5%
# a_mean_s2: 0.1043 bits (p=0.0000)
# Retention: 51.8%
# ndt_mean_s1: 0.1517 bits (p=0.0000)
# Retention: 75.3%
# ndt_mean_s2: 0.1525 bits (p=0.0000)
# Retention: 75.8%
# Mutual Information Summary (All Parameters):
# Primary Method: shrinkage_mi
# Raw MI: 0.2013 bits (p=0.0000)
# Conditional MI (all parameters): 0.1051 bits (p=0.0000)
# Overall Retention: 52.2%

# %% [markdown]
# # ELP Model 2

# %%
import NewMI

# Load your data
session1_path = 'Model2 ELP/Transformed_recoverd_param_ELP_S1_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'
session2_path = 'Model2 ELP/Transformed_recoverd_param_ELP_S2_second_100_2000_200_epoch_rt_acc_logAlphaSample.csv'

df_merged = NewMI.load_and_merge(session1_path, session2_path)

# Initialize analyzer
analyzer = NewMI.MutualInformationAnalyzer(df_merged)

# Define control variables
control_vars = ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']

# Run analysis
results = analyzer.analyze_alpha_reliability(
    feature='alpha_s1',
    target='alpha_s2',
    control_vars=control_vars,
    primary_method='shrinkage_mi'  # Use this method for calculations
)

# Print results
print("\nRaw Mutual Information Estimates:")
print(f"Gaussian MI: {results['gaussian_mi'][0]:.4f} bits (p={results['gaussian_mi'][1]:.4f})")
print(f"Adaptive Binning MI: {results['adaptive_binning_mi'][0]:.4f} bits (p={results['adaptive_binning_mi'][1]:.4f})")
print(f"Shrinkage MI: {results['shrinkage_mi'][0]:.4f} bits (p={results['shrinkage_mi'][1]:.4f})")

print("\nConditional Mutual Information (controlling for each parameter):")
for var, (cmi, p_value) in results['conditional_mi'].items():
    print(f"{var}: {cmi:.4f} bits (p={p_value:.4f})")
    print(f"Retention: {results['retention'][var]:.1f}%")

# Plot results
analyzer.plot_results(results)
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Available columns in session 1: ['Unnamed: 0', 'participant', 'v1', 'v2', 'a_mean_s1', 'ndt_mean_s1', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s1', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Available columns in session 2: ['Unnamed: 0', 'participant', 'v1', 'v2', 'a_mean_s2', 'ndt_mean_s2', 'alpha', 'accuracy_percentage', 'mean_log_rt', 'RT_mean_correct_error', 'mean_correct', 'mean_Crror', 'log_alpha_mean', 'alpha_capped', 'alpha_shifted', 'alpha_arcsin', 'alpha_arcsin_positive', 'alpha_boxcox_after_arcsin_s2', 'accuracy_arcsin', 'accuracy_arcsin_positive', 'accuracy_boxcox_after_arcsin']
# Using identifier column: participant
#
# Diagnostic Information for Conditional MI (All Parameters):
# Number of control variables: 4
# Control variables: ['a_mean_s1', 'a_mean_s2', 'ndt_mean_s1', 'ndt_mean_s2']
# Sample size: 806
# Dimensionality of control matrix: (806, 4)
#
# Correlations between control variables:
# a_mean_s1 - a_mean_s2: r = 0.6706
# a_mean_s1 - ndt_mean_s1: r = -0.0790
# a_mean_s1 - ndt_mean_s2: r = -0.0015
# a_mean_s2 - ndt_mean_s1: r = 0.0361
# a_mean_s2 - ndt_mean_s2: r = -0.1414
# ndt_mean_s1 - ndt_mean_s2: r = 0.6694
# Using bandwidth: 0.2000
#
# Summary statistics of log probabilities:
# log_px: mean = -0.1455, std = 0.4707
# log_py: mean = -0.1579, std = 0.5016
# log_pz: mean = 0.4380, std = 1.1138
# log_pxz: mean = 0.5731, std = 1.2394
# log_pyz: mean = 0.5516, std = 1.2554
# log_pxyz: mean = 0.8195, std = 1.3290
#
# Intermediate calculation steps:
# Mean(log_pxyz + log_pz): 1.2575
# Mean(log_pxz + log_pyz): 1.1247
# Final CMI: 0.1328
#
# Components contributing to CMI:
# Mean(log_pxyz): 0.8195
# Mean(log_pz): 0.4380
# Mean(log_pxz): 0.5731
# Mean(log_pyz): 0.5516
# CMI = 0.8195 + 0.4380 - 0.5731 - 0.5516 = 0.1328
# Permutation test p-value: 0.0000
#
# Raw Mutual Information Estimates:
# Gaussian MI: 0.3121 bits (p=0.0000)
# Adaptive Binning MI: 0.8720 bits (p=0.0000)
# Shrinkage MI: 0.2692 bits (p=0.0000)
#
# Conditional Mutual Information (controlling for each parameter):
# a_mean_s1: 0.1630 bits (p=0.0000)
# Retention: 60.5%
# a_mean_s2: 0.1636 bits (p=0.0000)
# Retention: 60.8%
# ndt_mean_s1: 0.2094 bits (p=0.0000)
# Retention: 77.8%
# ndt_mean_s2: 0.2151 bits (p=0.0000)
# Retention: 79.9%
# Mutual Information Summary (All Parameters):
# Primary Method: shrinkage_mi
# Raw MI: 0.2692 bits (p=0.0000)
# Conditional MI (all parameters): 0.1328 bits (p=0.0000)
# Overall Retention: 49.3%
